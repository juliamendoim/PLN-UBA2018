# %% [markdown]
# # Contando N-Gramas

# %%
from nltk.corpus import gutenberg
sents = list(gutenberg.sents('austen-emma.txt'))
sents[0]
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']']

# %% [markdown]
# Primero vemos cómo imprimir todos los trigramas de una sola oración:

# %%
sent = sents[0]

n = 3  # trigramas
for i in range(len(sent) - n + 1):
    print(sent[i:i+n])
# Out:
# ['[', 'Emma', 'by']
# ['Emma', 'by', 'Jane']
# ['by', 'Jane', 'Austen']
# ['Jane', 'Austen', '1816']
# ['Austen', '1816', ']']

# %% [markdown]
# Ahora veamos cómo contar los trigramas de todas las oraciones:

# %%
from collections import defaultdict

count = defaultdict(int)

for sent in sents:
    for i in range(len(sent) - n + 1):
        ngram = tuple(sent[i:i+n])  # los diccionarios no pueden guardar listas, pero sí tuplas
        count[ngram] += 1

# %%
count
# Out:
# defaultdict(int,
#             {('[', 'Emma', 'by'): 1,
#              ('Emma', 'by', 'Jane'): 1,
#              ('by', 'Jane', 'Austen'): 1,
#              ('Jane', 'Austen', '1816'): 1,
#              ('Austen', '1816', ']'): 1,
#              ('Emma', 'Woodhouse', ','): 4,
#              ('Woodhouse', ',', 'handsome'): 1,
#              (',', 'handsome', ','): 2,
#              ('handsome', ',', 'clever'): 1,
#              (',', 'clever', ','): 1,
#              ('clever', ',', 'and'): 3,
#              (',', 'and', 'rich'): 1,
#              ('and', 'rich', ','): 1,
#              ('rich', ',', 'with'): 1,
#              (',', 'with', 'a'): 43,
#              ('with', 'a', 'comfortable'): 1,
#              ('a', 'comfortable', 'home'): 2,
#              ('comfortable', 'home', 'and'): 1,
#              ('home', 'and', 'happy'): 1,
#              ('and', 'happy', 'disposition'): 1,
#              ('happy', 'disposition', ','): 1,
#              ('disposition', ',', 'seemed'): 1,
#              (',', 'seemed', 'to'): 4,
#              ('seemed', 'to', 'unite'): 1,
#              ('to', 'unite', 'some'): 1,
#              ('unite', 'some', 'of'): 1,
#              ('some', 'of', 'the'): 7,
#              ('of', 'the', 'best'): 3,
#              ('the', 'best', 'blessings'): 2,
#              ('best', 'blessings', 'of'): 2,
#              ('blessings', 'of', 'existence'): 2,
#              ('of', 'existence', ';'): 2,
#              ('existence', ';', 'and'): 1,
#              (';', 'and', 'had'): 5,
#              ('and', 'had', 'lived'): 2,
#              ('had', 'lived', 'nearly'): 1,
#              ('lived', 'nearly', 'twenty'): 1,
#              ('nearly', 'twenty', '-'): 1,
#              ('twenty', '-', 'one'): 1,
#              ('-', 'one', 'years'): 1,
#              ('one', 'years', 'in'): 1,
#              ('years', 'in', 'the'): 1,
#              ('in', 'the', 'world'): 49,
#              ('the', 'world', 'with'): 1,
#              ('world', 'with', 'very'): 1,
#              ('with', 'very', 'little'): 2,
#              ('very', 'little', 'to'): 3,
#              ('little', 'to', 'distress'): 1,
#              ('to', 'distress', 'or'): 1,
#              ('distress', 'or', 'vex'): 1,
#              ('or', 'vex', 'her'): 1,
#              ('vex', 'her', '.'): 1,
#              ('She', 'was', 'the'): 3,
#              ('was', 'the', 'youngest'): 2,
#              ('the', 'youngest', 'of'): 2,
#              ('youngest', 'of', 'the'): 2,
#              ('of', 'the', 'two'): 20,
#              ('the', 'two', 'daughters'): 2,
#              ('two', 'daughters', 'of'): 2,
#              ('daughters', 'of', 'a'): 2,
#              ('of', 'a', 'most'): 1,
#              ('a', 'most', 'affectionate'): 1,
#              ('most', 'affectionate', ','): 1,
#              ('affectionate', ',', 'indulgent'): 1,
#              (',', 'indulgent', 'father'): 1,
#              ('indulgent', 'father', ';'): 1,
#              ('father', ';', 'and'): 3,
#              ('and', 'had', ','): 1,
#              ('had', ',', 'in'): 3,
#              (',', 'in', 'consequence'): 1,
#              ('in', 'consequence', 'of'): 1,
#              ('consequence', 'of', 'her'): 1,
#              ('of', 'her', 'sister'): 2,
#              ('her', 'sister', "'"): 4,
#              ('sister', "'", 's'): 6,
#              ("'", 's', 'marriage'): 7,
#              ('s', 'marriage', ','): 3,
#              ('marriage', ',', 'been'): 1,
#              (',', 'been', 'mistress'): 1,
#              ('been', 'mistress', 'of'): 2,
#              ('mistress', 'of', 'his'): 1,
#              ('of', 'his', 'house'): 2,
#              ('his', 'house', 'from'): 1,
#              ('house', 'from', 'a'): 1,
#              ('from', 'a', 'very'): 1,
#              ('a', 'very', 'early'): 2,
#              ('very', 'early', 'period'): 1,
#              ('early', 'period', '.'): 1,
#              ('Her', 'mother', 'had'): 1,
#              ('mother', 'had', 'died'): 2,
#              ('had', 'died', 'too'): 1,
#              ('died', 'too', 'long'): 1,
#              ('too', 'long', 'ago'): 1,
#              ('long', 'ago', 'for'): 1,
#              ('ago', 'for', 'her'): 1,
#              ('for', 'her', 'to'): 16,
#              ('her', 'to', 'have'): 3,
#              ('to', 'have', 'more'): 2,
#              ('have', 'more', 'than'): 2,
#              ('more', 'than', 'an'): 3,
#              ('than', 'an', 'indistinct'): 1,
#              ('an', 'indistinct', 'remembrance'): 1,
#              ('indistinct', 'remembrance', 'of'): 1,
#              ('remembrance', 'of', 'her'): 1,
#              ('of', 'her', 'caresses'): 1,
#              ('her', 'caresses', ';'): 1,
#              ('caresses', ';', 'and'): 1,
#              (';', 'and', 'her'): 8,
#              ('and', 'her', 'place'): 1,
#              ('her', 'place', 'had'): 1,
#              ('place', 'had', 'been'): 1,
#              ('had', 'been', 'supplied'): 1,
#              ('been', 'supplied', 'by'): 1,
#              ('supplied', 'by', 'an'): 1,
#              ('by', 'an', 'excellent'): 1,
#              ('an', 'excellent', 'woman'): 1,
#              ('excellent', 'woman', 'as'): 1,
#              ('woman', 'as', 'governess'): 1,
#              ('as', 'governess', ','): 2,
#              ('governess', ',', 'who'): 1,
#              (',', 'who', 'had'): 30,
#              ('who', 'had', 'fallen'): 1,
#              ('had', 'fallen', 'little'): 1,
#              ('fallen', 'little', 'short'): 1,
#              ('little', 'short', 'of'): 1,
#              ('short', 'of', 'a'): 1,
#              ('of', 'a', 'mother'): 1,
#              ('a', 'mother', 'in'): 1,
#              ('mother', 'in', 'affection'): 1,
#              ('in', 'affection', '.'): 1,
#              ('Sixteen', 'years', 'had'): 1,
#              ('years', 'had', 'Miss'): 1,
#              ('had', 'Miss', 'Taylor'): 2,
#              ('Miss', 'Taylor', 'been'): 1,
#              ('Taylor', 'been', 'in'): 1,
#              ('been', 'in', 'Mr'): 1,
#              ('in', 'Mr', '.'): 13,
#              ('Mr', '.', 'Woodhouse'): 132,
#              ('.', 'Woodhouse', "'"): 25,
#              ('Woodhouse', "'", 's'): 36,
#              ("'", 's', 'family'): 7,
#              ('s', 'family', ','): 3,
#              ('family', ',', 'less'): 1,
#              (',', 'less', 'as'): 1,
#              ('less', 'as', 'a'): 1,
#              ('as', 'a', 'governess'): 1,
#              ('a', 'governess', 'than'): 1,
#              ('governess', 'than', 'a'): 1,
#              ('than', 'a', 'friend'): 1,
#              ('a', 'friend', ','): 7,
#              ('friend', ',', 'very'): 1,
#              (',', 'very', 'fond'): 1,
#              ('very', 'fond', 'of'): 9,
#              ('fond', 'of', 'both'): 1,
#              ('of', 'both', 'daughters'): 1,
#              ('both', 'daughters', ','): 1,
#              ('daughters', ',', 'but'): 1,
#              (',', 'but', 'particularly'): 4,
#              ('but', 'particularly', 'of'): 1,
#              ('particularly', 'of', 'Emma'): 1,
#              ('of', 'Emma', '.'): 2,
#              ('Between', '_them_', 'it'): 1,
#              ('_them_', 'it', 'was'): 1,
#              ('it', 'was', 'more'): 3,
#              ('was', 'more', 'the'): 1,
#              ('more', 'the', 'intimacy'): 1,
#              ('the', 'intimacy', 'of'): 1,
#              ('intimacy', 'of', 'sisters'): 1,
#              ('of', 'sisters', '.'): 1,
#              ('Even', 'before', 'Miss'): 1,
#              ('before', 'Miss', 'Taylor'): 1,
#              ('Miss', 'Taylor', 'had'): 4,
#              ('Taylor', 'had', 'ceased'): 1,
#              ('had', 'ceased', 'to'): 1,
#              ('ceased', 'to', 'hold'): 1,
#              ('to', 'hold', 'the'): 1,
#              ('hold', 'the', 'nominal'): 1,
#              ('the', 'nominal', 'office'): 1,
#              ('nominal', 'office', 'of'): 1,
#              ('office', 'of', 'governess'): 1,
#              ('of', 'governess', ','): 1,
#              ('governess', ',', 'the'): 1,
#              (',', 'the', 'mildness'): 1,
#              ('the', 'mildness', 'of'): 1,
#              ('mildness', 'of', 'her'): 1,
#              ('of', 'her', 'temper'): 2,
#              ('her', 'temper', 'had'): 1,
#              ('temper', 'had', 'hardly'): 1,
#              ('had', 'hardly', 'allowed'): 1,
#              ('hardly', 'allowed', 'her'): 1,
#              ('allowed', 'her', 'to'): 2,
#              ('her', 'to', 'impose'): 1,
#              ('to', 'impose', 'any'): 1,
#              ('impose', 'any', 'restraint'): 1,
#              ('any', 'restraint', ';'): 1,
#              ('restraint', ';', 'and'): 1,
#              (';', 'and', 'the'): 60,
#              ('and', 'the', 'shadow'): 1,
#              ('the', 'shadow', 'of'): 1,
#              ('shadow', 'of', 'authority'): 1,
#              ('of', 'authority', 'being'): 1,
#              ('authority', 'being', 'now'): 1,
#              ('being', 'now', 'long'): 1,
#              ('now', 'long', 'passed'): 1,
#              ('long', 'passed', 'away'): 2,
#              ('passed', 'away', ','): 2,
#              ('away', ',', 'they'): 1,
#              (',', 'they', 'had'): 6,
#              ('they', 'had', 'been'): 6,
#              ('had', 'been', 'living'): 1,
#              ('been', 'living', 'together'): 1,
#              ('living', 'together', 'as'): 1,
#              ('together', 'as', 'friend'): 1,
#              ('as', 'friend', 'and'): 1,
#              ('friend', 'and', 'friend'): 1,
#              ('and', 'friend', 'very'): 1,
#              ('friend', 'very', 'mutually'): 1,
#              ('very', 'mutually', 'attached'): 1,
#              ('mutually', 'attached', ','): 1,
#              ('attached', ',', 'and'): 1,
#              (',', 'and', 'Emma'): 19,
#              ('and', 'Emma', 'doing'): 1,
#              ('Emma', 'doing', 'just'): 1,
#              ('doing', 'just', 'what'): 2,
#              ('just', 'what', 'she'): 2,
#              ('what', 'she', 'liked'): 2,
#              ('she', 'liked', ';'): 1,
#              ('liked', ';', 'highly'): 1,
#              (';', 'highly', 'esteeming'): 1,
#              ('highly', 'esteeming', 'Miss'): 1,
#              ('esteeming', 'Miss', 'Taylor'): 1,
#              ('Miss', 'Taylor', "'"): 8,
#              ('Taylor', "'", 's'): 8,
#              ("'", 's', 'judgment'): 2,
#              ('s', 'judgment', ','): 1,
#              ('judgment', ',', 'but'): 1,
#              (',', 'but', 'directed'): 1,
#              ('but', 'directed', 'chiefly'): 1,
#              ('directed', 'chiefly', 'by'): 1,
#              ('chiefly', 'by', 'her'): 1,
#              ('by', 'her', 'own'): 4,
#              ('her', 'own', '.'): 8,
#              ('The', 'real', 'evils'): 1,
#              ('real', 'evils', ','): 1,
#              ('evils', ',', 'indeed'): 1,
#              (',', 'indeed', ','): 42,
#              ('indeed', ',', 'of'): 2,
#              (',', 'of', 'Emma'): 2,
#              ('of', 'Emma', "'"): 7,
#              ('Emma', "'", 's'): 79,
#              ("'", 's', 'situation'): 8,
#              ('s', 'situation', 'were'): 1,
#              ('situation', 'were', 'the'): 1,
#              ('were', 'the', 'power'): 1,
#              ('the', 'power', 'of'): 11,
#              ('power', 'of', 'having'): 1,
#              ('of', 'having', 'rather'): 1,
#              ('having', 'rather', 'too'): 1,
#              ('rather', 'too', 'much'): 4,
#              ('too', 'much', 'her'): 1,
#              ('much', 'her', 'own'): 1,
#              ('her', 'own', 'way'): 2,
#              ('own', 'way', ','): 4,
#              ('way', ',', 'and'): 7,
#              (',', 'and', 'a'): 47,
#              ('and', 'a', 'disposition'): 2,
#              ('a', 'disposition', 'to'): 2,
#              ('disposition', 'to', 'think'): 1,
#              ('to', 'think', 'a'): 1,
#              ('think', 'a', 'little'): 1,
#              ('a', 'little', 'too'): 4,
#              ('little', 'too', 'well'): 1,
#              ('too', 'well', 'of'): 1,
#              ('well', 'of', 'herself'): 1,
#              ('of', 'herself', ';'): 2,
#              ('herself', ';', 'these'): 1,
#              (';', 'these', 'were'): 1,
#              ('these', 'were', 'the'): 1,
#              ('were', 'the', 'disadvantages'): 1,
#              ('the', 'disadvantages', 'which'): 1,
#              ('disadvantages', 'which', 'threatened'): 1,
#              ('which', 'threatened', 'alloy'): 1,
#              ('threatened', 'alloy', 'to'): 1,
#              ('alloy', 'to', 'her'): 1,
#              ('to', 'her', 'many'): 1,
#              ('her', 'many', 'enjoyments'): 1,
#              ('many', 'enjoyments', '.'): 1,
#              ('The', 'danger', ','): 1,
#              ('danger', ',', 'however'): 1,
#              (',', 'however', ','): 88,
#              ('however', ',', 'was'): 10,
#              (',', 'was', 'at'): 1,
#              ('was', 'at', 'present'): 1,
#              ('at', 'present', 'so'): 2,
#              ('present', 'so', 'unperceived'): 1,
#              ('so', 'unperceived', ','): 1,
#              ('unperceived', ',', 'that'): 1,
#              (',', 'that', 'they'): 7,
#              ('that', 'they', 'did'): 1,
#              ('they', 'did', 'not'): 2,
#              ('did', 'not', 'by'): 2,
#              ('not', 'by', 'any'): 4,
#              ('by', 'any', 'means'): 7,
#              ('any', 'means', 'rank'): 1,
#              ('means', 'rank', 'as'): 1,
#              ('rank', 'as', 'misfortunes'): 1,
#              ('as', 'misfortunes', 'with'): 1,
#              ('misfortunes', 'with', 'her'): 1,
#              ('with', 'her', '.'): 11,
#              ('Sorrow', 'came', '--'): 1,
#              ('came', '--', 'a'): 1,
#              ('--', 'a', 'gentle'): 1,
#              ('a', 'gentle', 'sorrow'): 1,
#              ('gentle', 'sorrow', '--'): 1,
#              ('sorrow', '--', 'but'): 1,
#              ('--', 'but', 'not'): 6,
#              ('but', 'not', 'at'): 4,
#              ('not', 'at', 'all'): 27,
#              ('at', 'all', 'in'): 6,
#              ('all', 'in', 'the'): 4,
#              ('in', 'the', 'shape'): 2,
#              ('the', 'shape', 'of'): 2,
#              ('shape', 'of', 'any'): 1,
#              ('of', 'any', 'disagreeable'): 1,
#              ('any', 'disagreeable', 'consciousness'): 1,
#              ('disagreeable', 'consciousness', '.--'): 1,
#              ('consciousness', '.--', 'Miss'): 1,
#              ('.--', 'Miss', 'Taylor'): 1,
#              ('Miss', 'Taylor', 'married'): 1,
#              ('Taylor', 'married', '.'): 1,
#              ('It', 'was', 'Miss'): 1,
#              ('was', 'Miss', 'Taylor'): 1,
#              ("'", 's', 'loss'): 3,
#              ('s', 'loss', 'which'): 1,
#              ('loss', 'which', 'first'): 1,
#              ('which', 'first', 'brought'): 1,
#              ('first', 'brought', 'grief'): 1,
#              ('brought', 'grief', '.'): 1,
#              ('It', 'was', 'on'): 1,
#              ('was', 'on', 'the'): 5,
#              ('on', 'the', 'wedding'): 1,
#              ('the', 'wedding', '-'): 2,
#              ('wedding', '-', 'day'): 4,
#              ('-', 'day', 'of'): 1,
#              ('day', 'of', 'this'): 2,
#              ('of', 'this', 'beloved'): 1,
#              ('this', 'beloved', 'friend'): 1,
#              ('beloved', 'friend', 'that'): 1,
#              ('friend', 'that', 'Emma'): 1,
#              ('that', 'Emma', 'first'): 1,
#              ('Emma', 'first', 'sat'): 1,
#              ('first', 'sat', 'in'): 1,
#              ('sat', 'in', 'mournful'): 1,
#              ('in', 'mournful', 'thought'): 1,
#              ('mournful', 'thought', 'of'): 1,
#              ('thought', 'of', 'any'): 1,
#              ('of', 'any', 'continuance'): 1,
#              ('any', 'continuance', '.'): 1,
#              ('The', 'wedding', 'over'): 1,
#              ('wedding', 'over', ','): 1,
#              ('over', ',', 'and'): 7,
#              (',', 'and', 'the'): 89,
#              ('and', 'the', 'bride'): 1,
#              ('the', 'bride', '-'): 1,
#              ('bride', '-', 'people'): 1,
#              ('-', 'people', 'gone'): 1,
#              ('people', 'gone', ','): 1,
#              ('gone', ',', 'her'): 1,
#              (',', 'her', 'father'): 1,
#              ('her', 'father', 'and'): 8,
#              ('father', 'and', 'herself'): 3,
#              ('and', 'herself', 'were'): 1,
#              ('herself', 'were', 'left'): 1,
#              ('were', 'left', 'to'): 3,
#              ('left', 'to', 'dine'): 1,
#              ('to', 'dine', 'together'): 1,
#              ('dine', 'together', ','): 1,
#              ('together', ',', 'with'): 1,
#              (',', 'with', 'no'): 3,
#              ('with', 'no', 'prospect'): 1,
#              ('no', 'prospect', 'of'): 1,
#              ('prospect', 'of', 'a'): 1,
#              ('of', 'a', 'third'): 1,
#              ('a', 'third', 'to'): 1,
#              ('third', 'to', 'cheer'): 1,
#              ('to', 'cheer', 'a'): 1,
#              ('cheer', 'a', 'long'): 1,
#              ('a', 'long', 'evening'): 1,
#              ('long', 'evening', '.'): 1,
#              ('Her', 'father', 'composed'): 1,
#              ('father', 'composed', 'himself'): 1,
#              ('composed', 'himself', 'to'): 1,
#              ('himself', 'to', 'sleep'): 1,
#              ('to', 'sleep', 'after'): 1,
#              ('sleep', 'after', 'dinner'): 1,
#              ('after', 'dinner', ','): 7,
#              ('dinner', ',', 'as'): 4,
#              (',', 'as', 'usual'): 4,
#              ('as', 'usual', ','): 7,
#              ('usual', ',', 'and'): 2,
#              (',', 'and', 'she'): 48,
#              ('and', 'she', 'had'): 14,
#              ('she', 'had', 'then'): 3,
#              ('had', 'then', 'only'): 1,
#              ('then', 'only', 'to'): 1,
#              ('only', 'to', 'sit'): 1,
#              ('to', 'sit', 'and'): 4,
#              ('sit', 'and', 'think'): 1,
#              ('and', 'think', 'of'): 1,
#              ('think', 'of', 'what'): 1,
#              ('of', 'what', 'she'): 7,
#              ('what', 'she', 'had'): 17,
#              ('she', 'had', 'lost'): 1,
#              ('had', 'lost', '.'): 1,
#              ('The', 'event', 'had'): 1,
#              ('event', 'had', 'every'): 1,
#              ('had', 'every', 'promise'): 1,
#              ('every', 'promise', 'of'): 1,
#              ('promise', 'of', 'happiness'): 1,
#              ('of', 'happiness', 'for'): 1,
#              ('happiness', 'for', 'her'): 1,
#              ('for', 'her', 'friend'): 5,
#              ('her', 'friend', '.'): 6,
#              ('Mr', '.', 'Weston'): 162,
#              ('.', 'Weston', 'was'): 33,
#              ('Weston', 'was', 'a'): 4,
#              ('was', 'a', 'man'): 1,
#              ('a', 'man', 'of'): 10,
#              ('man', 'of', 'unexceptionable'): 1,
#              ('of', 'unexceptionable', 'character'): 1,
#              ('unexceptionable', 'character', ','): 1,
#              ('character', ',', 'easy'): 1,
#              (',', 'easy', 'fortune'): 1,
#              ('easy', 'fortune', ','): 1,
#              ('fortune', ',', 'suitable'): 1,
#              (',', 'suitable', 'age'): 1,
#              ('suitable', 'age', ','): 1,
#              ('age', ',', 'and'): 5,
#              (',', 'and', 'pleasant'): 1,
#              ('and', 'pleasant', 'manners'): 1,
#              ('pleasant', 'manners', ';'): 1,
#              ('manners', ';', 'and'): 2,
#              (';', 'and', 'there'): 14,
#              ('and', 'there', 'was'): 13,
#              ('there', 'was', 'some'): 1,
#              ('was', 'some', 'satisfaction'): 1,
#              ('some', 'satisfaction', 'in'): 1,
#              ('satisfaction', 'in', 'considering'): 1,
#              ('in', 'considering', 'with'): 1,
#              ('considering', 'with', 'what'): 1,
#              ('with', 'what', 'self'): 1,
#              ('what', 'self', '-'): 1,
#              ('self', '-', 'denying'): 1,
#              ('-', 'denying', ','): 1,
#              ('denying', ',', 'generous'): 1,
#              (',', 'generous', 'friendship'): 1,
#              ('generous', 'friendship', 'she'): 1,
#              ('friendship', 'she', 'had'): 1,
#              ('she', 'had', 'always'): 5,
#              ('had', 'always', 'wished'): 1,
#              ('always', 'wished', 'and'): 1,
#              ('wished', 'and', 'promoted'): 1,
#              ('and', 'promoted', 'the'): 1,
#              ('promoted', 'the', 'match'): 1,
#              ('the', 'match', ';'): 1,
#              ('match', ';', 'but'): 1,
#              (';', 'but', 'it'): 39,
#              ('but', 'it', 'was'): 29,
#              ('it', 'was', 'a'): 22,
#              ('was', 'a', 'black'): 1,
#              ('a', 'black', 'morning'): 1,
#              ('black', 'morning', "'"): 1,
#              ('morning', "'", 's'): 3,
#              ("'", 's', 'work'): 1,
#              ('s', 'work', 'for'): 1,
#              ('work', 'for', 'her'): 1,
#              ('for', 'her', '.'): 18,
#              ('The', 'want', 'of'): 2,
#              ('want', 'of', 'Miss'): 1,
#              ('of', 'Miss', 'Taylor'): 4,
#              ('Miss', 'Taylor', 'would'): 1,
#              ('Taylor', 'would', 'be'): 1,
#              ('would', 'be', 'felt'): 1,
#              ('be', 'felt', 'every'): 1,
#              ('felt', 'every', 'hour'): 1,
#              ('every', 'hour', 'of'): 3,
#              ('hour', 'of', 'every'): 1,
#              ('of', 'every', 'day'): 2,
#              ('every', 'day', '.'): 2,
#              ('She', 'recalled', 'her'): 1,
#              ('recalled', 'her', 'past'): 1,
#              ('her', 'past', 'kindness'): 1,
#              ('past', 'kindness', '--'): 1,
#              ('kindness', '--', 'the'): 1,
#              ('--', 'the', 'kindness'): 1,
#              ('the', 'kindness', ','): 1,
#              ('kindness', ',', 'the'): 1,
#              (',', 'the', 'affection'): 1,
#              ('the', 'affection', 'of'): 1,
#              ('affection', 'of', 'sixteen'): 1,
#              ('of', 'sixteen', 'years'): 1,
#              ('sixteen', 'years', '--'): 1,
#              ('years', '--', 'how'): 1,
#              ('--', 'how', 'she'): 2,
#              ('how', 'she', 'had'): 3,
#              ('she', 'had', 'taught'): 1,
#              ('had', 'taught', 'and'): 1,
#              ('taught', 'and', 'how'): 1,
#              ('and', 'how', 'she'): 2,
#              ('she', 'had', 'played'): 1,
#              ('had', 'played', 'with'): 1,
#              ('played', 'with', 'her'): 1,
#              ('with', 'her', 'from'): 1,
#              ('her', 'from', 'five'): 1,
#              ('from', 'five', 'years'): 1,
#              ('five', 'years', 'old'): 1,
#              ('years', 'old', '--'): 1,
#              ('old', '--', 'how'): 1,
#              ('she', 'had', 'devoted'): 1,
#              ('had', 'devoted', 'all'): 1,
#              ('devoted', 'all', 'her'): 1,
#              ('all', 'her', 'powers'): 1,
#              ('her', 'powers', 'to'): 1,
#              ('powers', 'to', 'attach'): 1,
#              ('to', 'attach', 'and'): 1,
#              ('attach', 'and', 'amuse'): 1,
#              ('and', 'amuse', 'her'): 2,
#              ('amuse', 'her', 'in'): 1,
#              ('her', 'in', 'health'): 1,
#              ('in', 'health', '--'): 1,
#              ('health', '--', 'and'): 1,
#              ('--', 'and', 'how'): 3,
#              ('and', 'how', 'nursed'): 1,
#              ('how', 'nursed', 'her'): 1,
#              ('nursed', 'her', 'through'): 1,
#              ('her', 'through', 'the'): 2,
#              ('through', 'the', 'various'): 1,
#              ('the', 'various', 'illnesses'): 1,
#              ('various', 'illnesses', 'of'): 1,
#              ('illnesses', 'of', 'childhood'): 1,
#              ('of', 'childhood', '.'): 1,
#              ('A', 'large', 'debt'): 1,
#              ('large', 'debt', 'of'): 1,
#              ('debt', 'of', 'gratitude'): 1,
#              ('of', 'gratitude', 'was'): 1,
#              ('gratitude', 'was', 'owing'): 1,
#              ('was', 'owing', 'here'): 1,
#              ('owing', 'here', ';'): 1,
#              ('here', ';', 'but'): 1,
#              (';', 'but', 'the'): 18,
#              ('but', 'the', 'intercourse'): 1,
#              ('the', 'intercourse', 'of'): 1,
#              ('intercourse', 'of', 'the'): 1,
#              ('of', 'the', 'last'): 2,
#              ('the', 'last', 'seven'): 1,
#              ('last', 'seven', 'years'): 1,
#              ('seven', 'years', ','): 1,
#              ('years', ',', 'the'): 1,
#              (',', 'the', 'equal'): 1,
#              ('the', 'equal', 'footing'): 1,
#              ('equal', 'footing', 'and'): 1,
#              ('footing', 'and', 'perfect'): 1,
#              ('and', 'perfect', 'unreserve'): 1,
#              ('perfect', 'unreserve', 'which'): 1,
#              ('unreserve', 'which', 'had'): 1,
#              ('which', 'had', 'soon'): 1,
#              ('had', 'soon', 'followed'): 1,
#              ('soon', 'followed', 'Isabella'): 1,
#              ('followed', 'Isabella', "'"): 1,
#              ('Isabella', "'", 's'): 13,
#              ('marriage', ',', 'on'): 1,
#              (',', 'on', 'their'): 1,
#              ('on', 'their', 'being'): 1,
#              ('their', 'being', 'left'): 1,
#              ('being', 'left', 'to'): 1,
#              ('left', 'to', 'each'): 1,
#              ('to', 'each', 'other'): 4,
#              ('each', 'other', ','): 6,
#              ('other', ',', 'was'): 2,
#              (',', 'was', 'yet'): 2,
#              ('was', 'yet', 'a'): 1,
#              ('yet', 'a', 'dearer'): 1,
#              ('a', 'dearer', ','): 1,
#              ('dearer', ',', 'tenderer'): 1,
#              (',', 'tenderer', 'recollection'): 1,
#              ('tenderer', 'recollection', '.'): 1,
#              ('She', 'had', 'been'): 7,
#              ('had', 'been', 'a'): 17,
#              ('been', 'a', 'friend'): 1,
#              ('a', 'friend', 'and'): 2,
#              ('friend', 'and', 'companion'): 1,
#              ('and', 'companion', 'such'): 1,
#              ('companion', 'such', 'as'): 1,
#              ('such', 'as', 'few'): 1,
#              ('as', 'few', 'possessed'): 1,
#              ('few', 'possessed', ':'): 1,
#              ('possessed', ':', 'intelligent'): 1,
#              (':', 'intelligent', ','): 1,
#              ('intelligent', ',', 'well'): 1,
#              (',', 'well', '-'): 6,
#              ('well', '-', 'informed'): 3,
#              ('-', 'informed', ','): 1,
#              ('informed', ',', 'useful'): 1,
#              (',', 'useful', ','): 2,
#              ('useful', ',', 'gentle'): 1,
#              (',', 'gentle', ','): 1,
#              ('gentle', ',', 'knowing'): 1,
#              (',', 'knowing', 'all'): 1,
#              ('knowing', 'all', 'the'): 1,
#              ('all', 'the', 'ways'): 1,
#              ('the', 'ways', 'of'): 3,
#              ('ways', 'of', 'the'): 2,
#              ('of', 'the', 'family'): 7,
#              ('the', 'family', ','): 6,
#              ('family', ',', 'interested'): 1,
#              (',', 'interested', 'in'): 1,
#              ('interested', 'in', 'all'): 1,
#              ('in', 'all', 'its'): 1,
#              ('all', 'its', 'concerns'): 1,
#              ('its', 'concerns', ','): 1,
#              ('concerns', ',', 'and'): 1,
#              (',', 'and', 'peculiarly'): 1,
#              ('and', 'peculiarly', 'interested'): 1,
#              ('peculiarly', 'interested', 'in'): 1,
#              ('interested', 'in', 'herself'): 1,
#              ('in', 'herself', ','): 3,
#              ('herself', ',', 'in'): 7,
#              (',', 'in', 'every'): 4,
#              ('in', 'every', 'pleasure'): 1,
#              ('every', 'pleasure', ','): 1,
#              ('pleasure', ',', 'every'): 1,
#              (',', 'every', 'scheme'): 1,
#              ('every', 'scheme', 'of'): 1,
#              ('scheme', 'of', 'hers'): 1,
#              ('of', 'hers', '--'): 1,
#              ('hers', '--', 'one'): 1,
#              ('--', 'one', 'to'): 1,
#              ('one', 'to', 'whom'): 2,
#              ('to', 'whom', 'she'): 7,
#              ('whom', 'she', 'could'): 3,
#              ('she', 'could', 'speak'): 3,
#              ('could', 'speak', 'every'): 1,
#              ('speak', 'every', 'thought'): 1,
#              ('every', 'thought', 'as'): 1,
#              ('thought', 'as', 'it'): 1,
#              ('as', 'it', 'arose'): 1,
#              ('it', 'arose', ','): 1,
#              ('arose', ',', 'and'): 1,
#              (',', 'and', 'who'): 12,
#              ('and', 'who', 'had'): 2,
#              ('who', 'had', 'such'): 1,
#              ('had', 'such', 'an'): 4,
#              ('such', 'an', 'affection'): 2,
#              ('an', 'affection', 'for'): 1,
#              ('affection', 'for', 'her'): 1,
#              ('for', 'her', 'as'): 3,
#              ('her', 'as', 'could'): 1,
#              ('as', 'could', 'never'): 1,
#              ('could', 'never', 'find'): 1,
#              ('never', 'find', 'fault'): 1,
#              ('find', 'fault', '.'): 1,
#              ('How', 'was', 'she'): 1,
#              ('was', 'she', 'to'): 2,
#              ('she', 'to', 'bear'): 1,
#              ('to', 'bear', 'the'): 1,
#              ('bear', 'the', 'change'): 1,
#              ('the', 'change', '?--'): 1,
#              ('change', '?--', 'It'): 1,
#              ('?--', 'It', 'was'): 3,
#              ('It', 'was', 'true'): 2,
#              ('was', 'true', 'that'): 2,
#              ('true', 'that', 'her'): 1,
#              ('that', 'her', 'friend'): 3,
#              ('her', 'friend', 'was'): 3,
#              ('friend', 'was', 'going'): 1,
#              ('was', 'going', 'only'): 1,
#              ('going', 'only', 'half'): 1,
#              ('only', 'half', 'a'): 4,
#              ('half', 'a', 'mile'): 6,
#              ('a', 'mile', 'from'): 3,
#              ('mile', 'from', 'them'): 2,
#              ('from', 'them', ';'): 1,
#              ('them', ';', 'but'): 3,
#              (';', 'but', 'Emma'): 9,
#              ('but', 'Emma', 'was'): 2,
#              ('Emma', 'was', 'aware'): 1,
#              ('was', 'aware', 'that'): 1,
#              ('aware', 'that', 'great'): 1,
#              ('that', 'great', 'must'): 1,
#              ('great', 'must', 'be'): 1,
#              ('must', 'be', 'the'): 9,
#              ('be', 'the', 'difference'): 1,
#              ('the', 'difference', 'between'): 2,
#              ('difference', 'between', 'a'): 1,
#              ('between', 'a', 'Mrs'): 1,
#              ('a', 'Mrs', '.'): 3,
#              ('Mrs', '.', 'Weston'): 249,
#              ('.', 'Weston', ','): 104,
#              ('Weston', ',', 'only'): 1,
#              (',', 'only', 'half'): 1,
#              ('from', 'them', ','): 1,
#              ('them', ',', 'and'): 20,
#              ('and', 'a', 'Miss'): 1,
#              ('a', 'Miss', 'Taylor'): 1,
#              ('Miss', 'Taylor', 'in'): 1,
#              ('Taylor', 'in', 'the'): 1,
#              ('in', 'the', 'house'): 5,
#              ('the', 'house', ';'): 5,
#              ('house', ';', 'and'): 3,
#              (';', 'and', 'with'): 13,
#              ('and', 'with', 'all'): 4,
#              ('with', 'all', 'her'): 7,
#              ('all', 'her', 'advantages'): 1,
#              ('her', 'advantages', ','): 1,
#              ('advantages', ',', 'natural'): 1,
#              (',', 'natural', 'and'): 1,
#              ('natural', 'and', 'domestic'): 1,
#              ('and', 'domestic', ','): 1,
#              ('domestic', ',', 'she'): 1,
#              (',', 'she', 'was'): 39,
#              ('she', 'was', 'now'): 4,
#              ('was', 'now', 'in'): 5,
#              ('now', 'in', 'great'): 1,
#              ('in', 'great', 'danger'): 1,
#              ('great', 'danger', 'of'): 1,
#              ('danger', 'of', 'suffering'): 1,
#              ('of', 'suffering', 'from'): 1,
#              ('suffering', 'from', 'intellectual'): 1,
#              ('from', 'intellectual', 'solitude'): 1,
#              ('intellectual', 'solitude', '.'): 1,
#              ('She', 'dearly', 'loved'): 1,
#              ('dearly', 'loved', 'her'): 1,
#              ('loved', 'her', 'father'): 1,
#              ('her', 'father', ','): 25,
#              ('father', ',', 'but'): 3,
#              (',', 'but', 'he'): 16,
#              ('but', 'he', 'was'): 7,
#              ('he', 'was', 'no'): 2,
#              ('was', 'no', 'companion'): 1,
#              ('no', 'companion', 'for'): 1,
#              ('companion', 'for', 'her'): 1,
#              ('He', 'could', 'not'): 9,
#              ('could', 'not', 'meet'): 1,
#              ('not', 'meet', 'her'): 1,
#              ('meet', 'her', 'in'): 1,
#              ('her', 'in', 'conversation'): 1,
#              ('in', 'conversation', ','): 1,
#              ('conversation', ',', 'rational'): 1,
#              (',', 'rational', 'or'): 1,
#              ('rational', 'or', 'playful'): 1,
#              ('or', 'playful', '.'): 1,
#              ('The', 'evil', 'of'): 2,
#              ('evil', 'of', 'the'): 3,
#              ('of', 'the', 'actual'): 1,
#              ('the', 'actual', 'disparity'): 1,
#              ('actual', 'disparity', 'in'): 1,
#              ('disparity', 'in', 'their'): 1,
#              ('in', 'their', 'ages'): 1,
#              ('their', 'ages', '('): 1,
#              ('ages', '(', 'and'): 1,
#              ('(', 'and', 'Mr'): 1,
#              ('and', 'Mr', '.'): 78,
#              ('.', 'Woodhouse', 'had'): 8,
#              ('Woodhouse', 'had', 'not'): 1,
#              ('had', 'not', 'married'): 2,
#              ('not', 'married', 'early'): 1,
#              ('married', 'early', ')'): 1,
#              ('early', ')', 'was'): 1,
#              (')', 'was', 'much'): 1,
#              ('was', 'much', 'increased'): 1,
#              ('much', 'increased', 'by'): 2,
#              ('increased', 'by', 'his'): 1,
#              ('by', 'his', 'constitution'): 1,
#              ('his', 'constitution', 'and'): 1,
#              ('constitution', 'and', 'habits'): 1,
#              ('and', 'habits', ';'): 2,
#              ('habits', ';', 'for'): 1,
#              (';', 'for', 'having'): 1,
#              ('for', 'having', 'been'): 1,
#              ('having', 'been', 'a'): 1,
#              ('been', 'a', 'valetudinarian'): 1,
#              ('a', 'valetudinarian', 'all'): 1,
#              ('valetudinarian', 'all', 'his'): 1,
#              ('all', 'his', 'life'): 3,
#              ('his', 'life', ','): 3,
#              ('life', ',', 'without'): 1,
#              (',', 'without', 'activity'): 1,
#              ('without', 'activity', 'of'): 1,
#              ('activity', 'of', 'mind'): 1,
#              ('of', 'mind', 'or'): 3,
#              ('mind', 'or', 'body'): 1,
#              ('or', 'body', ','): 1,
#              ('body', ',', 'he'): 2,
#              (',', 'he', 'was'): 27,
#              ('he', 'was', 'a'): 2,
#              ('was', 'a', 'much'): 1,
#              ('a', 'much', 'older'): 1,
#              ('much', 'older', 'man'): 1,
#              ('older', 'man', 'in'): 1,
#              ('man', 'in', 'ways'): 1,
#              ('in', 'ways', 'than'): 1,
#              ('ways', 'than', 'in'): 1,
#              ('than', 'in', 'years'): 1,
#              ('in', 'years', ';'): 1,
#              ('years', ';', 'and'): 2,
#              (';', 'and', 'though'): 27,
#              ('and', 'though', 'everywhere'): 1,
#              ('though', 'everywhere', 'beloved'): 1,
#              ('everywhere', 'beloved', 'for'): 1,
#              ('beloved', 'for', 'the'): 1,
#              ('for', 'the', 'friendliness'): 1,
#              ('the', 'friendliness', 'of'): 1,
#              ('friendliness', 'of', 'his'): 1,
#              ('of', 'his', 'heart'): 1,
#              ('his', 'heart', 'and'): 1,
#              ('heart', 'and', 'his'): 1,
#              ('and', 'his', 'amiable'): 1,
#              ('his', 'amiable', 'temper'): 1,
#              ('amiable', 'temper', ','): 1,
#              ('temper', ',', 'his'): 1,
#              (',', 'his', 'talents'): 1,
#              ('his', 'talents', 'could'): 1,
#              ('talents', 'could', 'not'): 1,
#              ('could', 'not', 'have'): 25,
#              ('not', 'have', 'recommended'): 1,
#              ('have', 'recommended', 'him'): 1,
#              ('recommended', 'him', 'at'): 1,
#              ('him', 'at', 'any'): 1,
#              ('at', 'any', 'time'): 12,
#              ('any', 'time', '.'): 2,
#              ('Her', 'sister', ','): 1,
#              ('sister', ',', 'though'): 1,
#              (',', 'though', 'comparatively'): 1,
#              ('though', 'comparatively', 'but'): 1,
#              ('comparatively', 'but', 'little'): 1,
#              ('but', 'little', 'removed'): 1,
#              ('little', 'removed', 'by'): 1,
#              ('removed', 'by', 'matrimony'): 1,
#              ('by', 'matrimony', ','): 1,
#              ('matrimony', ',', 'being'): 1,
#              (',', 'being', 'settled'): 1,
#              ('being', 'settled', 'in'): 1,
#              ('settled', 'in', 'London'): 1,
#              ('in', 'London', ','): 9,
#              ('London', ',', 'only'): 1,
#              (',', 'only', 'sixteen'): 1,
#              ('only', 'sixteen', 'miles'): 1,
#              ('sixteen', 'miles', 'off'): 1,
#              ('miles', 'off', ','): 1,
#              ('off', ',', 'was'): 1,
#              (',', 'was', 'much'): 1,
#              ('was', 'much', 'beyond'): 1,
#              ('much', 'beyond', 'her'): 1,
#              ('beyond', 'her', 'daily'): 1,
#              ('her', 'daily', 'reach'): 1,
#              ('daily', 'reach', ';'): 1,
#              ('reach', ';', 'and'): 1,
#              (';', 'and', 'many'): 1,
#              ('and', 'many', 'a'): 1,
#              ('many', 'a', 'long'): 1,
#              ('a', 'long', 'October'): 1,
#              ('long', 'October', 'and'): 1,
#              ('October', 'and', 'November'): 1,
#              ('and', 'November', 'evening'): 1,
#              ('November', 'evening', 'must'): 1,
#              ('evening', 'must', 'be'): 1,
#              ('must', 'be', 'struggled'): 1,
#              ('be', 'struggled', 'through'): 1,
#              ('struggled', 'through', 'at'): 1,
#              ('through', 'at', 'Hartfield'): 1,
#              ('at', 'Hartfield', ','): 27,
#              ('Hartfield', ',', 'before'): 2,
#              (',', 'before', 'Christmas'): 1,
#              ('before', 'Christmas', 'brought'): 1,
#              ('Christmas', 'brought', 'the'): 1,
#              ('brought', 'the', 'next'): 1,
#              ('the', 'next', 'visit'): 1,
#              ('next', 'visit', 'from'): 1,
#              ('visit', 'from', 'Isabella'): 1,
#              ('from', 'Isabella', 'and'): 1,
#              ('Isabella', 'and', 'her'): 1,
#              ('and', 'her', 'husband'): 2,
#              ('her', 'husband', ','): 6,
#              ('husband', ',', 'and'): 2,
#              (',', 'and', 'their'): 6,
#              ('and', 'their', 'little'): 1,
#              ('their', 'little', 'children'): 1,
#              ('little', 'children', ','): 1,
#              ('children', ',', 'to'): 1,
#              (',', 'to', 'fill'): 1,
#              ('to', 'fill', 'the'): 1,
#              ('fill', 'the', 'house'): 1,
#              ('the', 'house', ','): 9,
#              ('house', ',', 'and'): 7,
#              (',', 'and', 'give'): 4,
#              ('and', 'give', 'her'): 1,
#              ('give', 'her', 'pleasant'): 1,
#              ('her', 'pleasant', 'society'): 1,
#              ('pleasant', 'society', 'again'): 1,
#              ('society', 'again', '.'): 1,
#              ('Highbury', ',', 'the'): 2,
#              (',', 'the', 'large'): 1,
#              ('the', 'large', 'and'): 1,
#              ('large', 'and', 'populous'): 1,
#              ('and', 'populous', 'village'): 1,
#              ('populous', 'village', ','): 1,
#              ('village', ',', 'almost'): 1,
#              (',', 'almost', 'amounting'): 1,
#              ('almost', 'amounting', 'to'): 1,
#              ('amounting', 'to', 'a'): 1,
#              ('to', 'a', 'town'): 1,
#              ('a', 'town', ','): 1,
#              ('town', ',', 'to'): 1,
#              (',', 'to', 'which'): 3,
#              ('to', 'which', 'Hartfield'): 1,
#              ('which', 'Hartfield', ','): 1,
#              ('Hartfield', ',', 'in'): 2,
#              (',', 'in', 'spite'): 14,
#              ('in', 'spite', 'of'): 20,
#              ('spite', 'of', 'its'): 1,
#              ('of', 'its', 'separate'): 1,
#              ('its', 'separate', 'lawn'): 1,
#              ('separate', 'lawn', ','): 1,
#              ('lawn', ',', 'and'): 2,
#              (',', 'and', 'shrubberies'): 1,
#              ('and', 'shrubberies', ','): 1,
#              ('shrubberies', ',', 'and'): 1,
#              (',', 'and', 'name'): 1,
#              ('and', 'name', ','): 1,
#              ('name', ',', 'did'): 1,
#              (',', 'did', 'really'): 1,
#              ('did', 'really', 'belong'): 1,
#              ('really', 'belong', ','): 1,
#              ('belong', ',', 'afforded'): 1,
#              (',', 'afforded', 'her'): 1,
#              ('afforded', 'her', 'no'): 1,
#              ('her', 'no', 'equals'): 1,
#              ('no', 'equals', '.'): 1,
#              ('The', 'Woodhouses', 'were'): 1,
#              ('Woodhouses', 'were', 'first'): 1,
#              ('were', 'first', 'in'): 1,
#              ('first', 'in', 'consequence'): 1,
#              ('in', 'consequence', 'there'): 1,
#              ('consequence', 'there', '.'): 1,
#              ('All', 'looked', 'up'): 1,
#              ('looked', 'up', 'to'): 3,
#              ('up', 'to', 'them'): 1,
#              ('to', 'them', '.'): 2,
#              ('She', 'had', 'many'): 1,
#              ('had', 'many', 'acquaintance'): 1,
#              ('many', 'acquaintance', 'in'): 1,
#              ('acquaintance', 'in', 'the'): 2,
#              ('in', 'the', 'place'): 6,
#              ('the', 'place', ','): 8,
#              ('place', ',', 'for'): 1,
#              (',', 'for', 'her'): 3,
#              ('for', 'her', 'father'): 5,
#              ('her', 'father', 'was'): 4,
#              ('father', 'was', 'universally'): 1,
#              ('was', 'universally', 'civil'): 1,
#              ('universally', 'civil', ','): 1,
#              ('civil', ',', 'but'): 1,
#              (',', 'but', 'not'): 16,
#              ('but', 'not', 'one'): 1,
#              ('not', 'one', 'among'): 2,
#              ('one', 'among', 'them'): 1,
#              ('among', 'them', 'who'): 1,
#              ('them', 'who', 'could'): 1,
#              ('who', 'could', 'be'): 4,
#              ('could', 'be', 'accepted'): 1,
#              ('be', 'accepted', 'in'): 1,
#              ('accepted', 'in', 'lieu'): 1,
#              ('in', 'lieu', 'of'): 1,
#              ('lieu', 'of', 'Miss'): 1,
#              ('Miss', 'Taylor', 'for'): 1,
#              ('Taylor', 'for', 'even'): 1,
#              ('for', 'even', 'half'): 1,
#              ('even', 'half', 'a'): 2,
#              ('half', 'a', 'day'): 4,
#              ('a', 'day', '.'): 3,
#              ('It', 'was', 'a'): 31,
#              ('was', 'a', 'melancholy'): 1,
#              ('a', 'melancholy', 'change'): 2,
#              ('melancholy', 'change', ';'): 1,
#              ('change', ';', 'and'): 3,
#              (';', 'and', 'Emma'): 26,
#              ('and', 'Emma', 'could'): 8,
#              ('Emma', 'could', 'not'): 35,
#              ('could', 'not', 'but'): 20,
#              ('not', 'but', 'sigh'): 1,
#              ('but', 'sigh', 'over'): 1,
#              ('sigh', 'over', 'it'): 1,
#              ('over', 'it', ','): 3,
#              ('it', ',', 'and'): 31,
#              (',', 'and', 'wish'): 3,
#              ('and', 'wish', 'for'): 1,
#              ('wish', 'for', 'impossible'): 1,
#              ('for', 'impossible', 'things'): 1,
#              ('impossible', 'things', ','): 1,
#              ('things', ',', 'till'): 1,
#              ...})

# %% [markdown]
# El código sirve para n-gramas en general.
#
# Tareas pendientes:
# - Agregar marcadores de principio y final de oración
# - Contar n-gramas y (n-1)-gramas al mismo tiempo.

# %% [markdown]
# # Generando Lenguaje Natural
#
# El siguiente modelo de bigramas se aprende a partir de dos oraciones:
# - "el gato come pescado"
# - "la gata come salmón"

# %%
probs = {
    #'<s>': {'el': 0.5, 'la': 0.5},
    '<s>': {'el': 0.6, 'la': 0.2, 'los': 0.1, 'las': 0.1},
    'el': {'gato': 1.0},
    'gato': {'come': 1.0},
    'come': {'pescado': 0.5, 'salmón': 0.5},
    'pescado': {'.': 1.0},
    '.': {'</s>': 1.0},
    'la': {'gata': 1.0},
    'gata': {'come': 1.0},
    'salmón': {'.': 1.0},
}

list(probs['<s>'].items())  # convertir un diccionario a lista de pares
probs.values()
# Out:
# dict_values([{'el': 0.6, 'la': 0.2, 'los': 0.1, 'las': 0.1}, {'gato': 1.0}, {'come': 1.0}, {'pescado': 0.5, 'salmón': 0.5}, {'.': 1.0}, {'</s>': 1.0}, {'gata': 1.0}, {'come': 1.0}, {'.': 1.0}])

# %%
probs1 = {
    #'<s>': {'el': 0.5, 'la': 0.5},
    ('<s>','<s>'): {'el': 0.5, 'la': 0.5},
    ('<s>','el'): {'gato': 1.0},
    ('el','gato'): {'come': 1.0},
    ('gato','come'): {'pescado': 0.5, 'salmón': 0.5},
    ('come','pescado'): {'.': 1.0},
    ('come','salmón'): {'.': 1.0},
    ('.','</s>'): {'</s>': 1.0},
    ('<s>','la'): {'gata': 1.0},
    ('la','gata'): {'come': 1.0},
    ('gata','come'): {'pescado': 0.5, 'salmón': 0.5},
    ('salmón','.'): {'</s>': 1.0},
    ('pescado','.'): {'</s>':1.0},
}

list(probs1[ ('<s>','<s>')].items())  # convertir un diccionario a lista de pares
# Out:
# [('el', 0.5), ('la', 0.5)]

# %%
def ngramear(probs, rango):
    nuevo_dic = {}
    for key, value in probs.items():
        nuevo_key = key + tuple(list(value)[:rango])
        nuevo_dic[nuevo_key] = probs[tuple(list(nuevo_key))[rango:]]
    return nuevo_dic

#No lo terminé de hacer funcional

# %% [markdown]
# Cada entrada del diccionario contiene una distribución discreta finita para la palabra siguiente dada la palabra anterior. Samplear de una distribución discreta finita es tan fácil como samplear un número al azar entre 0 y 1 y ver en qué región cae (ver [Wikipedia](https://en.wikipedia.org/wiki/Pseudo-random_number_sampling#Finite_discrete_distributions)).
#
# Empezamos sampleando la primer palabra:

# %%
from random import random

def sample(problist):
    r = random()  # entre 0 y 1
    i = 0
    word, prob = problist[0]
    acum = prob
    while r > acum:
        i += 1
        word, prob = problist[i]
        acum += prob
    
    return  word

sample(list(probs[ ('<s>','<s>')].items()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-276-f66c7c3c7654> in <module>
#      13     return  word
#      14
# ---> 15 sample(list(probs[ ('<s>','<s>')].items()))
#
# KeyError: ('<s>', '<s>')

# %% [markdown]
# Podemos ver que el resultado del sampleo se corresponde con las probabilidades:

# %%
results = [sample(list(probs[ ('<s>','<s>')].items())) for i in range(1000)]

from collections import Counter
print(Counter(results))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-272-e145d56e2801> in <module>
# ----> 1 results = [sample(list(probs[ ('<s>','<s>')].items())) for i in range(1000)]
#       2
#       3 from collections import Counter
#       4 print(Counter(results))
#
# <ipython-input-272-e145d56e2801> in <listcomp>(.0)
# ----> 1 results = [sample(list(probs[ ('<s>','<s>')].items())) for i in range(1000)]
#       2
#       3 from collections import Counter
#       4 print(Counter(results))
#
# KeyError: ('<s>', '<s>')

# %% [markdown]
# **Observaciones:**
# - Si se ordena la lista de probabilidades de mayor a menor, el sampling es más rápido.
# - El sampling también se puede hacer usando [random.choices](https://docs.python.org/3/library/random.html#random.choices) de python
# ó [random.choice](https://stackoverflow.com/questions/11373192/generating-discrete-random-variables-with-specified-weights-using-scipy-or-numpy) de numpy.
#
# Ahora veamos cómo samplear una oración completa:

# %%
word =  ('<s>','<s>')
while word !=  ('</s>','</s>'):
    problist = list(probs1[word].items())
    word = (word[1],sample(problist))
    print(word)
# Out:
# ('<s>', 'la')
# ('la', 'gata')
# ('gata', 'come')
# ('come', 'salmón')
# ('salmón', '.')
# ('.', '</s>')
# ('</s>', '</s>')

# %%
def generate(prob_dic,ngram):
    cadena_inicial = tuple(['<s>',]*ngram)
    cadena_final = tuple(['</s>',]*ngram)
    word =  cadena_inicial
    print(word)
    while word !=  cadena_final:
        problist = list(prob_dic[word].items())
        print(problist)
        word = word+tuple(list(sample(problist)))
        print(word)

# %%
generate(probs1,2)
# Out:
# ('<s>', '<s>')
# [('el', 0.5), ('la', 0.5)]
# ('<s>', '<s>', 'l', 'a')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-286-e8406c7ea7bc> in <module>
# ----> 1 generate(probs1,2)
#
# <ipython-input-285-425bad5a1db8> in generate(prob_dic, ngram)
#       5     print(word)
#       6     while word !=  cadena_final:
# ----> 7         problist = list(prob_dic[word].items())
#       8         print(problist)
#       9         word = word+tuple(list(sample(problist)))
#
# KeyError: ('<s>', '<s>', 'l', 'a')

# %% [markdown]
# Acá se ve que se pueden generar oraciones nuevas (no vistas en tiempo de entrenamiento).
#
# Tareas pendientes:
# - adaptar el código a n-gramas en general: usar tuplas como claves en probs!
# - precalcular las listas ordenadas de mayor a menor (ver sorted_prob en los tests)

# %%
#Agregar marcadores de principio y final de oración
#Contar n-gramas y (n-1)-gramas al mismo tiempo.

from collections import defaultdict

def ngrams(sents, ngram):
    n = ngram
    m = ngram-1
    
    count = defaultdict(int)
    countmenos = defaultdict(int)
    
    for sent in sents:
        for i in range(n-1):
            sent.insert(0,'<s>')
            sent.append('</s>')
        for i in range(len(sent) - n + 1):
            ngram = tuple(sent[i:i+n])
            count[ngram] += 1
    for sent in sents:
        for i in range(m-1):
            sent.insert(0,'<s>')
            sent.append('</s>')
        for i in range(len(sent) - m + 1):
            ngrammenos = tuple(sent[i:i+m])
            countmenos[ngrammenos] += 1
   
    return count, countmenos

# %%
enegramas = ngrams(sents,3)

# %%
enegramas[0]
# Out:
# defaultdict(int,
#             {('<s>', '<s>', '['): 2,
#              ('<s>', '[', 'Emma'): 1,
#              ('[', 'Emma', 'by'): 1,
#              ('Emma', 'by', 'Jane'): 1,
#              ('by', 'Jane', 'Austen'): 1,
#              ('Jane', 'Austen', '1816'): 1,
#              ('Austen', '1816', ']'): 1,
#              ('1816', ']', '</s>'): 1,
#              (']', '</s>', '</s>'): 1,
#              ('<s>', '<s>', 'VOLUME'): 3,
#              ('<s>', 'VOLUME', 'I'): 1,
#              ('VOLUME', 'I', '</s>'): 1,
#              ('I', '</s>', '</s>'): 4,
#              ('<s>', '<s>', 'CHAPTER'): 55,
#              ('<s>', 'CHAPTER', 'I'): 3,
#              ('CHAPTER', 'I', '</s>'): 3,
#              ('<s>', '<s>', 'Emma'): 212,
#              ('<s>', 'Emma', 'Woodhouse'): 1,
#              ('Emma', 'Woodhouse', ','): 4,
#              ('Woodhouse', ',', 'handsome'): 1,
#              (',', 'handsome', ','): 2,
#              ('handsome', ',', 'clever'): 1,
#              (',', 'clever', ','): 1,
#              ('clever', ',', 'and'): 3,
#              (',', 'and', 'rich'): 1,
#              ('and', 'rich', ','): 1,
#              ('rich', ',', 'with'): 1,
#              (',', 'with', 'a'): 43,
#              ('with', 'a', 'comfortable'): 1,
#              ('a', 'comfortable', 'home'): 2,
#              ('comfortable', 'home', 'and'): 1,
#              ('home', 'and', 'happy'): 1,
#              ('and', 'happy', 'disposition'): 1,
#              ('happy', 'disposition', ','): 1,
#              ('disposition', ',', 'seemed'): 1,
#              (',', 'seemed', 'to'): 4,
#              ('seemed', 'to', 'unite'): 1,
#              ('to', 'unite', 'some'): 1,
#              ('unite', 'some', 'of'): 1,
#              ('some', 'of', 'the'): 7,
#              ('of', 'the', 'best'): 3,
#              ('the', 'best', 'blessings'): 2,
#              ('best', 'blessings', 'of'): 2,
#              ('blessings', 'of', 'existence'): 2,
#              ('of', 'existence', ';'): 2,
#              ('existence', ';', 'and'): 1,
#              (';', 'and', 'had'): 5,
#              ('and', 'had', 'lived'): 2,
#              ('had', 'lived', 'nearly'): 1,
#              ('lived', 'nearly', 'twenty'): 1,
#              ('nearly', 'twenty', '-'): 1,
#              ('twenty', '-', 'one'): 1,
#              ('-', 'one', 'years'): 1,
#              ('one', 'years', 'in'): 1,
#              ('years', 'in', 'the'): 1,
#              ('in', 'the', 'world'): 49,
#              ('the', 'world', 'with'): 1,
#              ('world', 'with', 'very'): 1,
#              ('with', 'very', 'little'): 2,
#              ('very', 'little', 'to'): 3,
#              ('little', 'to', 'distress'): 1,
#              ('to', 'distress', 'or'): 1,
#              ('distress', 'or', 'vex'): 1,
#              ('or', 'vex', 'her'): 1,
#              ('vex', 'her', '.'): 1,
#              ('her', '.', '</s>'): 110,
#              ('.', '</s>', '</s>'): 5143,
#              ('<s>', '<s>', 'She'): 460,
#              ('<s>', 'She', 'was'): 94,
#              ('She', 'was', 'the'): 3,
#              ('was', 'the', 'youngest'): 2,
#              ('the', 'youngest', 'of'): 2,
#              ('youngest', 'of', 'the'): 2,
#              ('of', 'the', 'two'): 20,
#              ('the', 'two', 'daughters'): 2,
#              ('two', 'daughters', 'of'): 2,
#              ('daughters', 'of', 'a'): 2,
#              ('of', 'a', 'most'): 1,
#              ('a', 'most', 'affectionate'): 1,
#              ('most', 'affectionate', ','): 1,
#              ('affectionate', ',', 'indulgent'): 1,
#              (',', 'indulgent', 'father'): 1,
#              ('indulgent', 'father', ';'): 1,
#              ('father', ';', 'and'): 3,
#              ('and', 'had', ','): 1,
#              ('had', ',', 'in'): 3,
#              (',', 'in', 'consequence'): 1,
#              ('in', 'consequence', 'of'): 1,
#              ('consequence', 'of', 'her'): 1,
#              ('of', 'her', 'sister'): 2,
#              ('her', 'sister', "'"): 4,
#              ('sister', "'", 's'): 6,
#              ("'", 's', 'marriage'): 7,
#              ('s', 'marriage', ','): 3,
#              ('marriage', ',', 'been'): 1,
#              (',', 'been', 'mistress'): 1,
#              ('been', 'mistress', 'of'): 2,
#              ('mistress', 'of', 'his'): 1,
#              ('of', 'his', 'house'): 2,
#              ('his', 'house', 'from'): 1,
#              ('house', 'from', 'a'): 1,
#              ('from', 'a', 'very'): 1,
#              ('a', 'very', 'early'): 2,
#              ('very', 'early', 'period'): 1,
#              ('early', 'period', '.'): 1,
#              ('period', '.', '</s>'): 2,
#              ('<s>', '<s>', 'Her'): 80,
#              ('<s>', 'Her', 'mother'): 1,
#              ('Her', 'mother', 'had'): 1,
#              ('mother', 'had', 'died'): 2,
#              ('had', 'died', 'too'): 1,
#              ('died', 'too', 'long'): 1,
#              ('too', 'long', 'ago'): 1,
#              ('long', 'ago', 'for'): 1,
#              ('ago', 'for', 'her'): 1,
#              ('for', 'her', 'to'): 16,
#              ('her', 'to', 'have'): 3,
#              ('to', 'have', 'more'): 2,
#              ('have', 'more', 'than'): 2,
#              ('more', 'than', 'an'): 3,
#              ('than', 'an', 'indistinct'): 1,
#              ('an', 'indistinct', 'remembrance'): 1,
#              ('indistinct', 'remembrance', 'of'): 1,
#              ('remembrance', 'of', 'her'): 1,
#              ('of', 'her', 'caresses'): 1,
#              ('her', 'caresses', ';'): 1,
#              ('caresses', ';', 'and'): 1,
#              (';', 'and', 'her'): 8,
#              ('and', 'her', 'place'): 1,
#              ('her', 'place', 'had'): 1,
#              ('place', 'had', 'been'): 1,
#              ('had', 'been', 'supplied'): 1,
#              ('been', 'supplied', 'by'): 1,
#              ('supplied', 'by', 'an'): 1,
#              ('by', 'an', 'excellent'): 1,
#              ('an', 'excellent', 'woman'): 1,
#              ('excellent', 'woman', 'as'): 1,
#              ('woman', 'as', 'governess'): 1,
#              ('as', 'governess', ','): 2,
#              ('governess', ',', 'who'): 1,
#              (',', 'who', 'had'): 30,
#              ('who', 'had', 'fallen'): 1,
#              ('had', 'fallen', 'little'): 1,
#              ('fallen', 'little', 'short'): 1,
#              ('little', 'short', 'of'): 1,
#              ('short', 'of', 'a'): 1,
#              ('of', 'a', 'mother'): 1,
#              ('a', 'mother', 'in'): 1,
#              ('mother', 'in', 'affection'): 1,
#              ('in', 'affection', '.'): 1,
#              ('affection', '.', '</s>'): 5,
#              ('<s>', '<s>', 'Sixteen'): 2,
#              ('<s>', 'Sixteen', 'years'): 1,
#              ('Sixteen', 'years', 'had'): 1,
#              ('years', 'had', 'Miss'): 1,
#              ('had', 'Miss', 'Taylor'): 2,
#              ('Miss', 'Taylor', 'been'): 1,
#              ('Taylor', 'been', 'in'): 1,
#              ('been', 'in', 'Mr'): 1,
#              ('in', 'Mr', '.'): 13,
#              ('Mr', '.', 'Woodhouse'): 132,
#              ('.', 'Woodhouse', "'"): 25,
#              ('Woodhouse', "'", 's'): 36,
#              ("'", 's', 'family'): 7,
#              ('s', 'family', ','): 3,
#              ('family', ',', 'less'): 1,
#              (',', 'less', 'as'): 1,
#              ('less', 'as', 'a'): 1,
#              ('as', 'a', 'governess'): 1,
#              ('a', 'governess', 'than'): 1,
#              ('governess', 'than', 'a'): 1,
#              ('than', 'a', 'friend'): 1,
#              ('a', 'friend', ','): 7,
#              ('friend', ',', 'very'): 1,
#              (',', 'very', 'fond'): 1,
#              ('very', 'fond', 'of'): 9,
#              ('fond', 'of', 'both'): 1,
#              ('of', 'both', 'daughters'): 1,
#              ('both', 'daughters', ','): 1,
#              ('daughters', ',', 'but'): 1,
#              (',', 'but', 'particularly'): 4,
#              ('but', 'particularly', 'of'): 1,
#              ('particularly', 'of', 'Emma'): 1,
#              ('of', 'Emma', '.'): 2,
#              ('Emma', '.', '</s>'): 44,
#              ('<s>', '<s>', 'Between'): 1,
#              ('<s>', 'Between', '_them_'): 1,
#              ('Between', '_them_', 'it'): 1,
#              ('_them_', 'it', 'was'): 1,
#              ('it', 'was', 'more'): 3,
#              ('was', 'more', 'the'): 1,
#              ('more', 'the', 'intimacy'): 1,
#              ('the', 'intimacy', 'of'): 1,
#              ('intimacy', 'of', 'sisters'): 1,
#              ('of', 'sisters', '.'): 1,
#              ('sisters', '.', '</s>'): 1,
#              ('<s>', '<s>', 'Even'): 8,
#              ('<s>', 'Even', 'before'): 1,
#              ('Even', 'before', 'Miss'): 1,
#              ('before', 'Miss', 'Taylor'): 1,
#              ('Miss', 'Taylor', 'had'): 4,
#              ('Taylor', 'had', 'ceased'): 1,
#              ('had', 'ceased', 'to'): 1,
#              ('ceased', 'to', 'hold'): 1,
#              ('to', 'hold', 'the'): 1,
#              ('hold', 'the', 'nominal'): 1,
#              ('the', 'nominal', 'office'): 1,
#              ('nominal', 'office', 'of'): 1,
#              ('office', 'of', 'governess'): 1,
#              ('of', 'governess', ','): 1,
#              ('governess', ',', 'the'): 1,
#              (',', 'the', 'mildness'): 1,
#              ('the', 'mildness', 'of'): 1,
#              ('mildness', 'of', 'her'): 1,
#              ('of', 'her', 'temper'): 2,
#              ('her', 'temper', 'had'): 1,
#              ('temper', 'had', 'hardly'): 1,
#              ('had', 'hardly', 'allowed'): 1,
#              ('hardly', 'allowed', 'her'): 1,
#              ('allowed', 'her', 'to'): 2,
#              ('her', 'to', 'impose'): 1,
#              ('to', 'impose', 'any'): 1,
#              ('impose', 'any', 'restraint'): 1,
#              ('any', 'restraint', ';'): 1,
#              ('restraint', ';', 'and'): 1,
#              (';', 'and', 'the'): 60,
#              ('and', 'the', 'shadow'): 1,
#              ('the', 'shadow', 'of'): 1,
#              ('shadow', 'of', 'authority'): 1,
#              ('of', 'authority', 'being'): 1,
#              ('authority', 'being', 'now'): 1,
#              ('being', 'now', 'long'): 1,
#              ('now', 'long', 'passed'): 1,
#              ('long', 'passed', 'away'): 2,
#              ('passed', 'away', ','): 2,
#              ('away', ',', 'they'): 1,
#              (',', 'they', 'had'): 6,
#              ('they', 'had', 'been'): 6,
#              ('had', 'been', 'living'): 1,
#              ('been', 'living', 'together'): 1,
#              ('living', 'together', 'as'): 1,
#              ('together', 'as', 'friend'): 1,
#              ('as', 'friend', 'and'): 1,
#              ('friend', 'and', 'friend'): 1,
#              ('and', 'friend', 'very'): 1,
#              ('friend', 'very', 'mutually'): 1,
#              ('very', 'mutually', 'attached'): 1,
#              ('mutually', 'attached', ','): 1,
#              ('attached', ',', 'and'): 1,
#              (',', 'and', 'Emma'): 19,
#              ('and', 'Emma', 'doing'): 1,
#              ('Emma', 'doing', 'just'): 1,
#              ('doing', 'just', 'what'): 2,
#              ('just', 'what', 'she'): 2,
#              ('what', 'she', 'liked'): 2,
#              ('she', 'liked', ';'): 1,
#              ('liked', ';', 'highly'): 1,
#              (';', 'highly', 'esteeming'): 1,
#              ('highly', 'esteeming', 'Miss'): 1,
#              ('esteeming', 'Miss', 'Taylor'): 1,
#              ('Miss', 'Taylor', "'"): 8,
#              ('Taylor', "'", 's'): 8,
#              ("'", 's', 'judgment'): 2,
#              ('s', 'judgment', ','): 1,
#              ('judgment', ',', 'but'): 1,
#              (',', 'but', 'directed'): 1,
#              ('but', 'directed', 'chiefly'): 1,
#              ('directed', 'chiefly', 'by'): 1,
#              ('chiefly', 'by', 'her'): 1,
#              ('by', 'her', 'own'): 4,
#              ('her', 'own', '.'): 8,
#              ('own', '.', '</s>'): 15,
#              ('<s>', '<s>', 'The'): 289,
#              ('<s>', 'The', 'real'): 1,
#              ('The', 'real', 'evils'): 1,
#              ('real', 'evils', ','): 1,
#              ('evils', ',', 'indeed'): 1,
#              (',', 'indeed', ','): 42,
#              ('indeed', ',', 'of'): 2,
#              (',', 'of', 'Emma'): 2,
#              ('of', 'Emma', "'"): 7,
#              ('Emma', "'", 's'): 79,
#              ("'", 's', 'situation'): 8,
#              ('s', 'situation', 'were'): 1,
#              ('situation', 'were', 'the'): 1,
#              ('were', 'the', 'power'): 1,
#              ('the', 'power', 'of'): 11,
#              ('power', 'of', 'having'): 1,
#              ('of', 'having', 'rather'): 1,
#              ('having', 'rather', 'too'): 1,
#              ('rather', 'too', 'much'): 4,
#              ('too', 'much', 'her'): 1,
#              ('much', 'her', 'own'): 1,
#              ('her', 'own', 'way'): 2,
#              ('own', 'way', ','): 4,
#              ('way', ',', 'and'): 7,
#              (',', 'and', 'a'): 47,
#              ('and', 'a', 'disposition'): 2,
#              ('a', 'disposition', 'to'): 2,
#              ('disposition', 'to', 'think'): 1,
#              ('to', 'think', 'a'): 1,
#              ('think', 'a', 'little'): 1,
#              ('a', 'little', 'too'): 4,
#              ('little', 'too', 'well'): 1,
#              ('too', 'well', 'of'): 1,
#              ('well', 'of', 'herself'): 1,
#              ('of', 'herself', ';'): 2,
#              ('herself', ';', 'these'): 1,
#              (';', 'these', 'were'): 1,
#              ('these', 'were', 'the'): 1,
#              ('were', 'the', 'disadvantages'): 1,
#              ('the', 'disadvantages', 'which'): 1,
#              ('disadvantages', 'which', 'threatened'): 1,
#              ('which', 'threatened', 'alloy'): 1,
#              ('threatened', 'alloy', 'to'): 1,
#              ('alloy', 'to', 'her'): 1,
#              ('to', 'her', 'many'): 1,
#              ('her', 'many', 'enjoyments'): 1,
#              ('many', 'enjoyments', '.'): 1,
#              ('enjoyments', '.', '</s>'): 1,
#              ('<s>', 'The', 'danger'): 2,
#              ('The', 'danger', ','): 1,
#              ('danger', ',', 'however'): 1,
#              (',', 'however', ','): 88,
#              ('however', ',', 'was'): 10,
#              (',', 'was', 'at'): 1,
#              ('was', 'at', 'present'): 1,
#              ('at', 'present', 'so'): 2,
#              ('present', 'so', 'unperceived'): 1,
#              ('so', 'unperceived', ','): 1,
#              ('unperceived', ',', 'that'): 1,
#              (',', 'that', 'they'): 7,
#              ('that', 'they', 'did'): 1,
#              ('they', 'did', 'not'): 2,
#              ('did', 'not', 'by'): 2,
#              ('not', 'by', 'any'): 4,
#              ('by', 'any', 'means'): 7,
#              ('any', 'means', 'rank'): 1,
#              ('means', 'rank', 'as'): 1,
#              ('rank', 'as', 'misfortunes'): 1,
#              ('as', 'misfortunes', 'with'): 1,
#              ('misfortunes', 'with', 'her'): 1,
#              ('with', 'her', '.'): 11,
#              ('<s>', '<s>', 'Sorrow'): 1,
#              ('<s>', 'Sorrow', 'came'): 1,
#              ('Sorrow', 'came', '--'): 1,
#              ('came', '--', 'a'): 1,
#              ('--', 'a', 'gentle'): 1,
#              ('a', 'gentle', 'sorrow'): 1,
#              ('gentle', 'sorrow', '--'): 1,
#              ('sorrow', '--', 'but'): 1,
#              ('--', 'but', 'not'): 6,
#              ('but', 'not', 'at'): 4,
#              ('not', 'at', 'all'): 27,
#              ('at', 'all', 'in'): 6,
#              ('all', 'in', 'the'): 4,
#              ('in', 'the', 'shape'): 2,
#              ('the', 'shape', 'of'): 2,
#              ('shape', 'of', 'any'): 1,
#              ('of', 'any', 'disagreeable'): 1,
#              ('any', 'disagreeable', 'consciousness'): 1,
#              ('disagreeable', 'consciousness', '.--'): 1,
#              ('consciousness', '.--', 'Miss'): 1,
#              ('.--', 'Miss', 'Taylor'): 1,
#              ('Miss', 'Taylor', 'married'): 1,
#              ('Taylor', 'married', '.'): 1,
#              ('married', '.', '</s>'): 7,
#              ('<s>', '<s>', 'It'): 295,
#              ('<s>', 'It', 'was'): 133,
#              ('It', 'was', 'Miss'): 1,
#              ('was', 'Miss', 'Taylor'): 1,
#              ("'", 's', 'loss'): 3,
#              ('s', 'loss', 'which'): 1,
#              ('loss', 'which', 'first'): 1,
#              ('which', 'first', 'brought'): 1,
#              ('first', 'brought', 'grief'): 1,
#              ('brought', 'grief', '.'): 1,
#              ('grief', '.', '</s>'): 1,
#              ('It', 'was', 'on'): 1,
#              ('was', 'on', 'the'): 5,
#              ('on', 'the', 'wedding'): 1,
#              ('the', 'wedding', '-'): 2,
#              ('wedding', '-', 'day'): 4,
#              ('-', 'day', 'of'): 1,
#              ('day', 'of', 'this'): 2,
#              ('of', 'this', 'beloved'): 1,
#              ('this', 'beloved', 'friend'): 1,
#              ('beloved', 'friend', 'that'): 1,
#              ('friend', 'that', 'Emma'): 1,
#              ('that', 'Emma', 'first'): 1,
#              ('Emma', 'first', 'sat'): 1,
#              ('first', 'sat', 'in'): 1,
#              ('sat', 'in', 'mournful'): 1,
#              ('in', 'mournful', 'thought'): 1,
#              ('mournful', 'thought', 'of'): 1,
#              ('thought', 'of', 'any'): 1,
#              ('of', 'any', 'continuance'): 1,
#              ('any', 'continuance', '.'): 1,
#              ('continuance', '.', '</s>'): 1,
#              ('<s>', 'The', 'wedding'): 3,
#              ('The', 'wedding', 'over'): 1,
#              ('wedding', 'over', ','): 1,
#              ('over', ',', 'and'): 7,
#              (',', 'and', 'the'): 89,
#              ('and', 'the', 'bride'): 1,
#              ('the', 'bride', '-'): 1,
#              ('bride', '-', 'people'): 1,
#              ('-', 'people', 'gone'): 1,
#              ('people', 'gone', ','): 1,
#              ('gone', ',', 'her'): 1,
#              (',', 'her', 'father'): 1,
#              ('her', 'father', 'and'): 8,
#              ('father', 'and', 'herself'): 3,
#              ('and', 'herself', 'were'): 1,
#              ('herself', 'were', 'left'): 1,
#              ('were', 'left', 'to'): 3,
#              ('left', 'to', 'dine'): 1,
#              ('to', 'dine', 'together'): 1,
#              ('dine', 'together', ','): 1,
#              ('together', ',', 'with'): 1,
#              (',', 'with', 'no'): 3,
#              ('with', 'no', 'prospect'): 1,
#              ('no', 'prospect', 'of'): 1,
#              ('prospect', 'of', 'a'): 1,
#              ('of', 'a', 'third'): 1,
#              ('a', 'third', 'to'): 1,
#              ('third', 'to', 'cheer'): 1,
#              ('to', 'cheer', 'a'): 1,
#              ('cheer', 'a', 'long'): 1,
#              ('a', 'long', 'evening'): 1,
#              ('long', 'evening', '.'): 1,
#              ('evening', '.', '</s>'): 7,
#              ('<s>', 'Her', 'father'): 8,
#              ('Her', 'father', 'composed'): 1,
#              ('father', 'composed', 'himself'): 1,
#              ('composed', 'himself', 'to'): 1,
#              ('himself', 'to', 'sleep'): 1,
#              ('to', 'sleep', 'after'): 1,
#              ('sleep', 'after', 'dinner'): 1,
#              ('after', 'dinner', ','): 7,
#              ('dinner', ',', 'as'): 4,
#              (',', 'as', 'usual'): 4,
#              ('as', 'usual', ','): 7,
#              ('usual', ',', 'and'): 2,
#              (',', 'and', 'she'): 48,
#              ('and', 'she', 'had'): 14,
#              ('she', 'had', 'then'): 3,
#              ('had', 'then', 'only'): 1,
#              ('then', 'only', 'to'): 1,
#              ('only', 'to', 'sit'): 1,
#              ('to', 'sit', 'and'): 4,
#              ('sit', 'and', 'think'): 1,
#              ('and', 'think', 'of'): 1,
#              ('think', 'of', 'what'): 1,
#              ('of', 'what', 'she'): 7,
#              ('what', 'she', 'had'): 17,
#              ('she', 'had', 'lost'): 1,
#              ('had', 'lost', '.'): 1,
#              ('lost', '.', '</s>'): 2,
#              ('<s>', 'The', 'event'): 4,
#              ('The', 'event', 'had'): 1,
#              ('event', 'had', 'every'): 1,
#              ('had', 'every', 'promise'): 1,
#              ('every', 'promise', 'of'): 1,
#              ('promise', 'of', 'happiness'): 1,
#              ('of', 'happiness', 'for'): 1,
#              ('happiness', 'for', 'her'): 1,
#              ('for', 'her', 'friend'): 5,
#              ('her', 'friend', '.'): 6,
#              ('friend', '.', '</s>'): 21,
#              ('<s>', '<s>', 'Mr'): 185,
#              ('<s>', 'Mr', '.'): 185,
#              ('Mr', '.', 'Weston'): 162,
#              ('.', 'Weston', 'was'): 33,
#              ('Weston', 'was', 'a'): 4,
#              ('was', 'a', 'man'): 1,
#              ('a', 'man', 'of'): 10,
#              ('man', 'of', 'unexceptionable'): 1,
#              ('of', 'unexceptionable', 'character'): 1,
#              ('unexceptionable', 'character', ','): 1,
#              ('character', ',', 'easy'): 1,
#              (',', 'easy', 'fortune'): 1,
#              ('easy', 'fortune', ','): 1,
#              ('fortune', ',', 'suitable'): 1,
#              (',', 'suitable', 'age'): 1,
#              ('suitable', 'age', ','): 1,
#              ('age', ',', 'and'): 5,
#              (',', 'and', 'pleasant'): 1,
#              ('and', 'pleasant', 'manners'): 1,
#              ('pleasant', 'manners', ';'): 1,
#              ('manners', ';', 'and'): 2,
#              (';', 'and', 'there'): 14,
#              ('and', 'there', 'was'): 13,
#              ('there', 'was', 'some'): 1,
#              ('was', 'some', 'satisfaction'): 1,
#              ('some', 'satisfaction', 'in'): 1,
#              ('satisfaction', 'in', 'considering'): 1,
#              ('in', 'considering', 'with'): 1,
#              ('considering', 'with', 'what'): 1,
#              ('with', 'what', 'self'): 1,
#              ('what', 'self', '-'): 1,
#              ('self', '-', 'denying'): 1,
#              ('-', 'denying', ','): 1,
#              ('denying', ',', 'generous'): 1,
#              (',', 'generous', 'friendship'): 1,
#              ('generous', 'friendship', 'she'): 1,
#              ('friendship', 'she', 'had'): 1,
#              ('she', 'had', 'always'): 5,
#              ('had', 'always', 'wished'): 1,
#              ('always', 'wished', 'and'): 1,
#              ('wished', 'and', 'promoted'): 1,
#              ('and', 'promoted', 'the'): 1,
#              ('promoted', 'the', 'match'): 1,
#              ('the', 'match', ';'): 1,
#              ('match', ';', 'but'): 1,
#              (';', 'but', 'it'): 39,
#              ('but', 'it', 'was'): 29,
#              ('it', 'was', 'a'): 22,
#              ('was', 'a', 'black'): 1,
#              ('a', 'black', 'morning'): 1,
#              ('black', 'morning', "'"): 1,
#              ('morning', "'", 's'): 3,
#              ("'", 's', 'work'): 1,
#              ('s', 'work', 'for'): 1,
#              ('work', 'for', 'her'): 1,
#              ('for', 'her', '.'): 18,
#              ('<s>', 'The', 'want'): 2,
#              ('The', 'want', 'of'): 2,
#              ('want', 'of', 'Miss'): 1,
#              ('of', 'Miss', 'Taylor'): 4,
#              ('Miss', 'Taylor', 'would'): 1,
#              ('Taylor', 'would', 'be'): 1,
#              ('would', 'be', 'felt'): 1,
#              ('be', 'felt', 'every'): 1,
#              ('felt', 'every', 'hour'): 1,
#              ('every', 'hour', 'of'): 3,
#              ('hour', 'of', 'every'): 1,
#              ('of', 'every', 'day'): 2,
#              ('every', 'day', '.'): 2,
#              ('day', '.', '</s>'): 18,
#              ('<s>', 'She', 'recalled'): 1,
#              ('She', 'recalled', 'her'): 1,
#              ('recalled', 'her', 'past'): 1,
#              ('her', 'past', 'kindness'): 1,
#              ('past', 'kindness', '--'): 1,
#              ('kindness', '--', 'the'): 1,
#              ('--', 'the', 'kindness'): 1,
#              ('the', 'kindness', ','): 1,
#              ('kindness', ',', 'the'): 1,
#              (',', 'the', 'affection'): 1,
#              ('the', 'affection', 'of'): 1,
#              ('affection', 'of', 'sixteen'): 1,
#              ('of', 'sixteen', 'years'): 1,
#              ('sixteen', 'years', '--'): 1,
#              ('years', '--', 'how'): 1,
#              ('--', 'how', 'she'): 2,
#              ('how', 'she', 'had'): 3,
#              ('she', 'had', 'taught'): 1,
#              ('had', 'taught', 'and'): 1,
#              ('taught', 'and', 'how'): 1,
#              ('and', 'how', 'she'): 2,
#              ('she', 'had', 'played'): 1,
#              ('had', 'played', 'with'): 1,
#              ('played', 'with', 'her'): 1,
#              ('with', 'her', 'from'): 1,
#              ('her', 'from', 'five'): 1,
#              ('from', 'five', 'years'): 1,
#              ('five', 'years', 'old'): 1,
#              ('years', 'old', '--'): 1,
#              ('old', '--', 'how'): 1,
#              ('she', 'had', 'devoted'): 1,
#              ('had', 'devoted', 'all'): 1,
#              ('devoted', 'all', 'her'): 1,
#              ('all', 'her', 'powers'): 1,
#              ('her', 'powers', 'to'): 1,
#              ('powers', 'to', 'attach'): 1,
#              ('to', 'attach', 'and'): 1,
#              ('attach', 'and', 'amuse'): 1,
#              ('and', 'amuse', 'her'): 2,
#              ('amuse', 'her', 'in'): 1,
#              ('her', 'in', 'health'): 1,
#              ('in', 'health', '--'): 1,
#              ('health', '--', 'and'): 1,
#              ('--', 'and', 'how'): 3,
#              ('and', 'how', 'nursed'): 1,
#              ('how', 'nursed', 'her'): 1,
#              ('nursed', 'her', 'through'): 1,
#              ('her', 'through', 'the'): 2,
#              ('through', 'the', 'various'): 1,
#              ('the', 'various', 'illnesses'): 1,
#              ('various', 'illnesses', 'of'): 1,
#              ('illnesses', 'of', 'childhood'): 1,
#              ('of', 'childhood', '.'): 1,
#              ('childhood', '.', '</s>'): 1,
#              ('<s>', '<s>', 'A'): 93,
#              ('<s>', 'A', 'large'): 2,
#              ('A', 'large', 'debt'): 1,
#              ('large', 'debt', 'of'): 1,
#              ('debt', 'of', 'gratitude'): 1,
#              ('of', 'gratitude', 'was'): 1,
#              ('gratitude', 'was', 'owing'): 1,
#              ('was', 'owing', 'here'): 1,
#              ('owing', 'here', ';'): 1,
#              ('here', ';', 'but'): 1,
#              (';', 'but', 'the'): 18,
#              ('but', 'the', 'intercourse'): 1,
#              ('the', 'intercourse', 'of'): 1,
#              ('intercourse', 'of', 'the'): 1,
#              ('of', 'the', 'last'): 2,
#              ('the', 'last', 'seven'): 1,
#              ('last', 'seven', 'years'): 1,
#              ('seven', 'years', ','): 1,
#              ('years', ',', 'the'): 1,
#              (',', 'the', 'equal'): 1,
#              ('the', 'equal', 'footing'): 1,
#              ('equal', 'footing', 'and'): 1,
#              ('footing', 'and', 'perfect'): 1,
#              ('and', 'perfect', 'unreserve'): 1,
#              ('perfect', 'unreserve', 'which'): 1,
#              ('unreserve', 'which', 'had'): 1,
#              ('which', 'had', 'soon'): 1,
#              ('had', 'soon', 'followed'): 1,
#              ('soon', 'followed', 'Isabella'): 1,
#              ('followed', 'Isabella', "'"): 1,
#              ('Isabella', "'", 's'): 13,
#              ('marriage', ',', 'on'): 1,
#              (',', 'on', 'their'): 1,
#              ('on', 'their', 'being'): 1,
#              ('their', 'being', 'left'): 1,
#              ('being', 'left', 'to'): 1,
#              ('left', 'to', 'each'): 1,
#              ('to', 'each', 'other'): 4,
#              ('each', 'other', ','): 6,
#              ('other', ',', 'was'): 2,
#              (',', 'was', 'yet'): 2,
#              ('was', 'yet', 'a'): 1,
#              ('yet', 'a', 'dearer'): 1,
#              ('a', 'dearer', ','): 1,
#              ('dearer', ',', 'tenderer'): 1,
#              (',', 'tenderer', 'recollection'): 1,
#              ('tenderer', 'recollection', '.'): 1,
#              ('recollection', '.', '</s>'): 1,
#              ('<s>', 'She', 'had'): 67,
#              ('She', 'had', 'been'): 7,
#              ('had', 'been', 'a'): 17,
#              ('been', 'a', 'friend'): 1,
#              ('a', 'friend', 'and'): 2,
#              ('friend', 'and', 'companion'): 1,
#              ('and', 'companion', 'such'): 1,
#              ('companion', 'such', 'as'): 1,
#              ('such', 'as', 'few'): 1,
#              ('as', 'few', 'possessed'): 1,
#              ('few', 'possessed', ':'): 1,
#              ('possessed', ':', 'intelligent'): 1,
#              (':', 'intelligent', ','): 1,
#              ('intelligent', ',', 'well'): 1,
#              (',', 'well', '-'): 6,
#              ('well', '-', 'informed'): 3,
#              ('-', 'informed', ','): 1,
#              ('informed', ',', 'useful'): 1,
#              (',', 'useful', ','): 2,
#              ('useful', ',', 'gentle'): 1,
#              (',', 'gentle', ','): 1,
#              ('gentle', ',', 'knowing'): 1,
#              (',', 'knowing', 'all'): 1,
#              ('knowing', 'all', 'the'): 1,
#              ('all', 'the', 'ways'): 1,
#              ('the', 'ways', 'of'): 3,
#              ('ways', 'of', 'the'): 2,
#              ('of', 'the', 'family'): 7,
#              ('the', 'family', ','): 6,
#              ('family', ',', 'interested'): 1,
#              (',', 'interested', 'in'): 1,
#              ('interested', 'in', 'all'): 1,
#              ('in', 'all', 'its'): 1,
#              ('all', 'its', 'concerns'): 1,
#              ('its', 'concerns', ','): 1,
#              ('concerns', ',', 'and'): 1,
#              (',', 'and', 'peculiarly'): 1,
#              ('and', 'peculiarly', 'interested'): 1,
#              ('peculiarly', 'interested', 'in'): 1,
#              ('interested', 'in', 'herself'): 1,
#              ('in', 'herself', ','): 3,
#              ('herself', ',', 'in'): 7,
#              (',', 'in', 'every'): 4,
#              ('in', 'every', 'pleasure'): 1,
#              ('every', 'pleasure', ','): 1,
#              ('pleasure', ',', 'every'): 1,
#              (',', 'every', 'scheme'): 1,
#              ('every', 'scheme', 'of'): 1,
#              ('scheme', 'of', 'hers'): 1,
#              ('of', 'hers', '--'): 1,
#              ('hers', '--', 'one'): 1,
#              ('--', 'one', 'to'): 1,
#              ('one', 'to', 'whom'): 2,
#              ('to', 'whom', 'she'): 7,
#              ('whom', 'she', 'could'): 3,
#              ('she', 'could', 'speak'): 3,
#              ('could', 'speak', 'every'): 1,
#              ('speak', 'every', 'thought'): 1,
#              ('every', 'thought', 'as'): 1,
#              ('thought', 'as', 'it'): 1,
#              ('as', 'it', 'arose'): 1,
#              ('it', 'arose', ','): 1,
#              ('arose', ',', 'and'): 1,
#              (',', 'and', 'who'): 12,
#              ('and', 'who', 'had'): 2,
#              ('who', 'had', 'such'): 1,
#              ('had', 'such', 'an'): 4,
#              ('such', 'an', 'affection'): 2,
#              ('an', 'affection', 'for'): 1,
#              ('affection', 'for', 'her'): 1,
#              ('for', 'her', 'as'): 3,
#              ('her', 'as', 'could'): 1,
#              ('as', 'could', 'never'): 1,
#              ('could', 'never', 'find'): 1,
#              ('never', 'find', 'fault'): 1,
#              ('find', 'fault', '.'): 1,
#              ('fault', '.', '</s>'): 3,
#              ('<s>', '<s>', 'How'): 56,
#              ('<s>', 'How', 'was'): 1,
#              ('How', 'was', 'she'): 1,
#              ('was', 'she', 'to'): 2,
#              ('she', 'to', 'bear'): 1,
#              ('to', 'bear', 'the'): 1,
#              ('bear', 'the', 'change'): 1,
#              ('the', 'change', '?--'): 1,
#              ('change', '?--', 'It'): 1,
#              ('?--', 'It', 'was'): 3,
#              ('It', 'was', 'true'): 2,
#              ('was', 'true', 'that'): 2,
#              ('true', 'that', 'her'): 1,
#              ('that', 'her', 'friend'): 3,
#              ('her', 'friend', 'was'): 3,
#              ('friend', 'was', 'going'): 1,
#              ('was', 'going', 'only'): 1,
#              ('going', 'only', 'half'): 1,
#              ('only', 'half', 'a'): 4,
#              ('half', 'a', 'mile'): 6,
#              ('a', 'mile', 'from'): 3,
#              ('mile', 'from', 'them'): 2,
#              ('from', 'them', ';'): 1,
#              ('them', ';', 'but'): 3,
#              (';', 'but', 'Emma'): 9,
#              ('but', 'Emma', 'was'): 2,
#              ('Emma', 'was', 'aware'): 1,
#              ('was', 'aware', 'that'): 1,
#              ('aware', 'that', 'great'): 1,
#              ('that', 'great', 'must'): 1,
#              ('great', 'must', 'be'): 1,
#              ('must', 'be', 'the'): 9,
#              ('be', 'the', 'difference'): 1,
#              ('the', 'difference', 'between'): 2,
#              ('difference', 'between', 'a'): 1,
#              ('between', 'a', 'Mrs'): 1,
#              ('a', 'Mrs', '.'): 3,
#              ('Mrs', '.', 'Weston'): 249,
#              ('.', 'Weston', ','): 104,
#              ('Weston', ',', 'only'): 1,
#              (',', 'only', 'half'): 1,
#              ('from', 'them', ','): 1,
#              ('them', ',', 'and'): 20,
#              ('and', 'a', 'Miss'): 1,
#              ('a', 'Miss', 'Taylor'): 1,
#              ('Miss', 'Taylor', 'in'): 1,
#              ('Taylor', 'in', 'the'): 1,
#              ('in', 'the', 'house'): 5,
#              ('the', 'house', ';'): 5,
#              ('house', ';', 'and'): 3,
#              (';', 'and', 'with'): 13,
#              ('and', 'with', 'all'): 4,
#              ('with', 'all', 'her'): 7,
#              ('all', 'her', 'advantages'): 1,
#              ('her', 'advantages', ','): 1,
#              ('advantages', ',', 'natural'): 1,
#              (',', 'natural', 'and'): 1,
#              ('natural', 'and', 'domestic'): 1,
#              ('and', 'domestic', ','): 1,
#              ('domestic', ',', 'she'): 1,
#              (',', 'she', 'was'): 39,
#              ('she', 'was', 'now'): 4,
#              ('was', 'now', 'in'): 5,
#              ('now', 'in', 'great'): 1,
#              ('in', 'great', 'danger'): 1,
#              ('great', 'danger', 'of'): 1,
#              ('danger', 'of', 'suffering'): 1,
#              ('of', 'suffering', 'from'): 1,
#              ('suffering', 'from', 'intellectual'): 1,
#              ('from', 'intellectual', 'solitude'): 1,
#              ('intellectual', 'solitude', '.'): 1,
#              ('solitude', '.', '</s>'): 1,
#              ('<s>', 'She', 'dearly'): 1,
#              ('She', 'dearly', 'loved'): 1,
#              ('dearly', 'loved', 'her'): 1,
#              ('loved', 'her', 'father'): 1,
#              ('her', 'father', ','): 25,
#              ('father', ',', 'but'): 3,
#              (',', 'but', 'he'): 16,
#              ('but', 'he', 'was'): 7,
#              ('he', 'was', 'no'): 2,
#              ('was', 'no', 'companion'): 1,
#              ('no', 'companion', 'for'): 1,
#              ('companion', 'for', 'her'): 1,
#              ('<s>', '<s>', 'He'): 358,
#              ('<s>', 'He', 'could'): 11,
#              ('He', 'could', 'not'): 9,
#              ('could', 'not', 'meet'): 1,
#              ('not', 'meet', 'her'): 1,
#              ('meet', 'her', 'in'): 1,
#              ('her', 'in', 'conversation'): 1,
#              ('in', 'conversation', ','): 1,
#              ('conversation', ',', 'rational'): 1,
#              (',', 'rational', 'or'): 1,
#              ('rational', 'or', 'playful'): 1,
#              ('or', 'playful', '.'): 1,
#              ('playful', '.', '</s>'): 1,
#              ('<s>', 'The', 'evil'): 2,
#              ('The', 'evil', 'of'): 2,
#              ('evil', 'of', 'the'): 3,
#              ('of', 'the', 'actual'): 1,
#              ('the', 'actual', 'disparity'): 1,
#              ('actual', 'disparity', 'in'): 1,
#              ('disparity', 'in', 'their'): 1,
#              ('in', 'their', 'ages'): 1,
#              ('their', 'ages', '('): 1,
#              ('ages', '(', 'and'): 1,
#              ('(', 'and', 'Mr'): 1,
#              ('and', 'Mr', '.'): 78,
#              ('.', 'Woodhouse', 'had'): 8,
#              ('Woodhouse', 'had', 'not'): 1,
#              ('had', 'not', 'married'): 2,
#              ('not', 'married', 'early'): 1,
#              ('married', 'early', ')'): 1,
#              ('early', ')', 'was'): 1,
#              (')', 'was', 'much'): 1,
#              ('was', 'much', 'increased'): 1,
#              ('much', 'increased', 'by'): 2,
#              ('increased', 'by', 'his'): 1,
#              ('by', 'his', 'constitution'): 1,
#              ('his', 'constitution', 'and'): 1,
#              ('constitution', 'and', 'habits'): 1,
#              ('and', 'habits', ';'): 2,
#              ('habits', ';', 'for'): 1,
#              (';', 'for', 'having'): 1,
#              ('for', 'having', 'been'): 1,
#              ('having', 'been', 'a'): 1,
#              ('been', 'a', 'valetudinarian'): 1,
#              ('a', 'valetudinarian', 'all'): 1,
#              ('valetudinarian', 'all', 'his'): 1,
#              ('all', 'his', 'life'): 3,
#              ('his', 'life', ','): 3,
#              ('life', ',', 'without'): 1,
#              (',', 'without', 'activity'): 1,
#              ('without', 'activity', 'of'): 1,
#              ('activity', 'of', 'mind'): 1,
#              ('of', 'mind', 'or'): 3,
#              ('mind', 'or', 'body'): 1,
#              ('or', 'body', ','): 1,
#              ('body', ',', 'he'): 2,
#              (',', 'he', 'was'): 27,
#              ('he', 'was', 'a'): 2,
#              ('was', 'a', 'much'): 1,
#              ('a', 'much', 'older'): 1,
#              ('much', 'older', 'man'): 1,
#              ('older', 'man', 'in'): 1,
#              ('man', 'in', 'ways'): 1,
#              ('in', 'ways', 'than'): 1,
#              ('ways', 'than', 'in'): 1,
#              ('than', 'in', 'years'): 1,
#              ('in', 'years', ';'): 1,
#              ('years', ';', 'and'): 2,
#              (';', 'and', 'though'): 27,
#              ('and', 'though', 'everywhere'): 1,
#              ('though', 'everywhere', 'beloved'): 1,
#              ('everywhere', 'beloved', 'for'): 1,
#              ('beloved', 'for', 'the'): 1,
#              ('for', 'the', 'friendliness'): 1,
#              ('the', 'friendliness', 'of'): 1,
#              ('friendliness', 'of', 'his'): 1,
#              ('of', 'his', 'heart'): 1,
#              ('his', 'heart', 'and'): 1,
#              ('heart', 'and', 'his'): 1,
#              ('and', 'his', 'amiable'): 1,
#              ('his', 'amiable', 'temper'): 1,
#              ('amiable', 'temper', ','): 1,
#              ('temper', ',', 'his'): 1,
#              (',', 'his', 'talents'): 1,
#              ('his', 'talents', 'could'): 1,
#              ('talents', 'could', 'not'): 1,
#              ('could', 'not', 'have'): 25,
#              ('not', 'have', 'recommended'): 1,
#              ('have', 'recommended', 'him'): 1,
#              ('recommended', 'him', 'at'): 1,
#              ('him', 'at', 'any'): 1,
#              ('at', 'any', 'time'): 12,
#              ('any', 'time', '.'): 2,
#              ('time', '.', '</s>'): 26,
#              ('<s>', 'Her', 'sister'): 1,
#              ('Her', 'sister', ','): 1,
#              ('sister', ',', 'though'): 1,
#              (',', 'though', 'comparatively'): 1,
#              ('though', 'comparatively', 'but'): 1,
#              ('comparatively', 'but', 'little'): 1,
#              ('but', 'little', 'removed'): 1,
#              ('little', 'removed', 'by'): 1,
#              ('removed', 'by', 'matrimony'): 1,
#              ('by', 'matrimony', ','): 1,
#              ('matrimony', ',', 'being'): 1,
#              (',', 'being', 'settled'): 1,
#              ('being', 'settled', 'in'): 1,
#              ('settled', 'in', 'London'): 1,
#              ('in', 'London', ','): 9,
#              ('London', ',', 'only'): 1,
#              (',', 'only', 'sixteen'): 1,
#              ('only', 'sixteen', 'miles'): 1,
#              ('sixteen', 'miles', 'off'): 1,
#              ('miles', 'off', ','): 1,
#              ('off', ',', 'was'): 1,
#              (',', 'was', 'much'): 1,
#              ('was', 'much', 'beyond'): 1,
#              ('much', 'beyond', 'her'): 1,
#              ('beyond', 'her', 'daily'): 1,
#              ('her', 'daily', 'reach'): 1,
#              ('daily', 'reach', ';'): 1,
#              ('reach', ';', 'and'): 1,
#              (';', 'and', 'many'): 1,
#              ('and', 'many', 'a'): 1,
#              ('many', 'a', 'long'): 1,
#              ('a', 'long', 'October'): 1,
#              ('long', 'October', 'and'): 1,
#              ('October', 'and', 'November'): 1,
#              ('and', 'November', 'evening'): 1,
#              ('November', 'evening', 'must'): 1,
#              ('evening', 'must', 'be'): 1,
#              ('must', 'be', 'struggled'): 1,
#              ('be', 'struggled', 'through'): 1,
#              ('struggled', 'through', 'at'): 1,
#              ('through', 'at', 'Hartfield'): 1,
#              ('at', 'Hartfield', ','): 27,
#              ('Hartfield', ',', 'before'): 2,
#              (',', 'before', 'Christmas'): 1,
#              ('before', 'Christmas', 'brought'): 1,
#              ('Christmas', 'brought', 'the'): 1,
#              ('brought', 'the', 'next'): 1,
#              ('the', 'next', 'visit'): 1,
#              ('next', 'visit', 'from'): 1,
#              ('visit', 'from', 'Isabella'): 1,
#              ('from', 'Isabella', 'and'): 1,
#              ('Isabella', 'and', 'her'): 1,
#              ('and', 'her', 'husband'): 2,
#              ('her', 'husband', ','): 6,
#              ('husband', ',', 'and'): 2,
#              (',', 'and', 'their'): 6,
#              ('and', 'their', 'little'): 1,
#              ('their', 'little', 'children'): 1,
#              ('little', 'children', ','): 1,
#              ('children', ',', 'to'): 1,
#              (',', 'to', 'fill'): 1,
#              ('to', 'fill', 'the'): 1,
#              ('fill', 'the', 'house'): 1,
#              ('the', 'house', ','): 9,
#              ('house', ',', 'and'): 7,
#              (',', 'and', 'give'): 4,
#              ('and', 'give', 'her'): 1,
#              ('give', 'her', 'pleasant'): 1,
#              ('her', 'pleasant', 'society'): 1,
#              ('pleasant', 'society', 'again'): 1,
#              ('society', 'again', '.'): 1,
#              ('again', '.', '</s>'): 48,
#              ('<s>', '<s>', 'Highbury'): 2,
#              ('<s>', 'Highbury', ','): 2,
#              ('Highbury', ',', 'the'): 2,
#              (',', 'the', 'large'): 1,
#              ('the', 'large', 'and'): 1,
#              ('large', 'and', 'populous'): 1,
#              ('and', 'populous', 'village'): 1,
#              ('populous', 'village', ','): 1,
#              ('village', ',', 'almost'): 1,
#              (',', 'almost', 'amounting'): 1,
#              ('almost', 'amounting', 'to'): 1,
#              ('amounting', 'to', 'a'): 1,
#              ('to', 'a', 'town'): 1,
#              ('a', 'town', ','): 1,
#              ('town', ',', 'to'): 1,
#              (',', 'to', 'which'): 3,
#              ('to', 'which', 'Hartfield'): 1,
#              ('which', 'Hartfield', ','): 1,
#              ('Hartfield', ',', 'in'): 2,
#              (',', 'in', 'spite'): 14,
#              ('in', 'spite', 'of'): 20,
#              ('spite', 'of', 'its'): 1,
#              ('of', 'its', 'separate'): 1,
#              ('its', 'separate', 'lawn'): 1,
#              ('separate', 'lawn', ','): 1,
#              ('lawn', ',', 'and'): 2,
#              (',', 'and', 'shrubberies'): 1,
#              ('and', 'shrubberies', ','): 1,
#              ('shrubberies', ',', 'and'): 1,
#              (',', 'and', 'name'): 1,
#              ('and', 'name', ','): 1,
#              ...})
